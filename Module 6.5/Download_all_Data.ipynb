# %% [markdown]
# # **Downloaded all Jane Austen's books, and all similar authors' books**

# %%
import os
import requests
import time
import hashlib
import re
import string
from bs4 import BeautifulSoup

BASE_URL = "https://www.gutenberg.org"

# Pages to scrape ebook IDs from: one author page and several subject pages.
PAGES_TO_SCRAPE = [
    "https://www.gutenberg.org/ebooks/author/68",  # Jane Austen
    "https://www.gutenberg.org/ebooks/22964", # All of Jane Austen Topics, I'm reading many authors cause original Jane Austen's length won't do it
    "https://www.gutenberg.org/ebooks/subject/104",
    "https://www.gutenberg.org/ebooks/subject/1702",
    "https://www.gutenberg.org/ebooks/subject/1699",
    "https://www.gutenberg.org/ebooks/subject/2487",
    "https://www.gutenberg.org/ebooks/subject/2489",
    "https://www.gutenberg.org/ebooks/subject/2514",
    "https://www.gutenberg.org/ebooks/subject/2545",
    "https://www.gutenberg.org/ebooks/subject/2906",
    "https://www.gutenberg.org/ebooks/subject/18493",
    "https://www.gutenberg.org/ebooks/subject/18494",
]

def get_ebook_ids(page_url):
    """
    Scrape a Gutenberg page (author or subject) to extract unique ebook IDs.
    Assumes links to ebooks are in the format "/ebooks/<id>".
    """
    try:
        response = requests.get(page_url)
        response.raise_for_status()
    except Exception as e:
        print(f"Error fetching {page_url}: {e}")
        return set()

    soup = BeautifulSoup(response.text, "html.parser")
    ebook_ids = set()
    for link in soup.find_all("a", href=True):
        href = link["href"]
        # The format is expected to be /ebooks/<id>
        if href.startswith("/ebooks/"):
            parts = href.split("/")
            if parts[-1].isdigit():
                ebook_ids.add(parts[-1])
    print(f"Found {len(ebook_ids)} ebooks from {page_url}")
    return ebook_ids

def get_plain_text_link(ebook_id):
    """Attempt to find the plain text link for an ebook."""
    ebook_page_url = f"{BASE_URL}/ebooks/{ebook_id}"
    try:
        response = requests.get(ebook_page_url)
        response.raise_for_status()
    except Exception as e:
        print(f"Error fetching ebook page {ebook_page_url}: {e}")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    # Try to find a link labeled "Plain Text UTF-8"
    link = soup.find("a", string="Plain Text UTF-8")
    if link and link.has_attr("href"):
        return BASE_URL + link["href"]

    # Fallback: try "Plain Text"
    link = soup.find("a", string="Plain Text")
    if link and link.has_attr("href"):
        return BASE_URL + link["href"]

    return None

def get_html_link(ebook_id):
    """
    Attempt to find the HTML version link for the ebook using the "Read online (web)" label.
    """
    ebook_page_url = f"{BASE_URL}/ebooks/{ebook_id}"
    try:
        response = requests.get(ebook_page_url)
        response.raise_for_status()
    except Exception as e:
        print(f"Error fetching ebook page {ebook_page_url}: {e}")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    link = soup.find("a", string=re.compile(r"read online\s*\(web\)", re.IGNORECASE))
    if link and link.has_attr("href"):
        href = link["href"]
        # If the URL is relative, prepend the base URL.
        if not href.startswith("http"):
            href = BASE_URL + href
        return href
    return None

def download_text(url):
    """Download text content from a given URL."""
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text
    except Exception as e:
        print(f"Error downloading {url}: {e}")
    return None

def extract_text_from_html(html_content):
    """Extract plain text from HTML content."""
    soup = BeautifulSoup(html_content, "html.parser")
    for script_or_style in soup(["script", "style"]):
        script_or_style.decompose()
    return soup.get_text(separator="\n")

def normalize_text(text):
    """
    Clean and normalize the ebook text.

    - Remove header: Everything before the start marker (if present).
    - Remove footer: Everything after any end marker (including variants such as fragments).
    - Remove mentions of "Project Gutenberg".
    - Normalize quotes, capitalization, punctuation, and whitespace.
    """
    # Remove header: everything before the start marker, if found.
    start_match = re.search(r'\*\*\* START OF THE PROJECT GUTENBERG EBOOK', text, re.IGNORECASE)
    if start_match:
        text = text[start_match.end():]

    # Remove footer: any content starting with an end marker (including fragment markers)
    text = re.split(r'\*\*\* END OF THE PROJECT GUTENBERG EBOOK.*', text, flags=re.IGNORECASE)[0]

    # Further cleaning: remove "Project Gutenberg" mentions
    text = text.replace("Project Gutenberg", "").replace("Gutenberg", "")
    text = text.replace("\r", "")
    text = text.replace("“", "\"").replace("”", "\"")

    # Mark capital letters at word boundaries with a caret then lowercase (similar to your preprocessing)
    text = re.sub(r"(?<![a-zA-Z])([A-Z])", lambda m: f"^{m.group(0).lower()}", text)
    text = re.sub(r"([A-Z])", lambda m: m.group(0).lower(), text)

    # Normalize whitespace and separate punctuation with spaces.
    text = re.sub(r"\s+", " ", text)
    text = re.sub("([{}])".format(re.escape(string.punctuation)), r" \1 ", text)
    text = re.sub(r"\s+", " ", text)

    return text.strip()

def get_ebook_content(ebook_id):
    """
    Get the content of an ebook.
    First, try downloading the plain text version.
    If not available, fall back to the HTML version ("Read online (web)") and extract its text.
    """
    text_link = get_plain_text_link(ebook_id)
    if text_link:
        print(f"Using plain text for ebook {ebook_id}: {text_link}")
        content = download_text(text_link)
        if content:
            return content
    # Fall back to HTML if plain text is unavailable.
    html_link = get_html_link(ebook_id)
    if html_link:
        print(f"Falling back to HTML for ebook {ebook_id}: {html_link}")
        html_content = download_text(html_link)
        if html_content:
            return extract_text_from_html(html_content)
    print(f"No downloadable content found for ebook {ebook_id}.")
    return None

def compile_corpus(ebook_ids):
    """
    Download all ebooks, clean and normalize the text, remove duplicates,
    and compile them into one text corpus.
    """
    corpus = ""
    seen_hashes = set()
    for ebook_id in ebook_ids:
        print(f"Processing ebook ID: {ebook_id}")
        raw_content = get_ebook_content(ebook_id)
        if raw_content:
            clean_content = normalize_text(raw_content)
            content_hash = hashlib.md5(clean_content.encode("utf-8")).hexdigest()
            if content_hash in seen_hashes:
                print(f"Duplicate content detected for ebook {ebook_id}, skipping.")
            else:
                seen_hashes.add(content_hash)
                corpus += f"\n\n=== Ebook ID {ebook_id} ===\n\n"
                corpus += clean_content
        else:
            print(f"Skipping ebook {ebook_id} due to lack of content.")
        time.sleep(2)
    return corpus

if __name__ == "__main__":
    all_ebook_ids = set()
    for page in PAGES_TO_SCRAPE:
        ids = get_ebook_ids(page)
        all_ebook_ids = all_ebook_ids.union(ids)
    print(f"Total unique ebook IDs gathered: {len(all_ebook_ids)}")

    corpus = compile_corpus(all_ebook_ids)
    output_file = "combined_corpus.txt"
    with open(output_file, "w", encoding="utf-8") as f:
        f.write(corpus)
    print(f"Compilation complete. Corpus saved to {output_file}.")
# Out:
# Found 25 ebooks from https://www.gutenberg.org/ebooks/author/68
# Processing ebook ID: 75410
# Using plain text for ebook 75410: https://www.gutenberg.org/ebooks/75410.txt.utf-8
# Processing ebook ID: 394
# Using plain text for ebook 394: https://www.gutenberg.org/ebooks/394.txt.utf-8
# Processing ebook ID: 3056
# Using plain text for ebook 3056: https://www.gutenberg.org/ebooks/3056.txt.utf-8
# Processing ebook ID: 1837
# Using plain text for ebook 1837: https://www.gutenberg.org/ebooks/1837.txt.utf-8
# Processing ebook ID: 22953
# No downloadable content found for ebook 22953.
# Skipping ebook 22953 due to lack of content.
# Processing ebook ID: 678
# Using plain text for ebook 678: https://www.gutenberg.org/ebooks/678.txt.utf-8
# Processing ebook ID: 68
# Using plain text for ebook 68: https://www.gutenberg.org/ebooks/68.txt.utf-8
# Processing ebook ID: 946
# Using plain text for ebook 946: https://www.gutenberg.org/ebooks/946.txt.utf-8
# Processing ebook ID: 1342
# Using plain text for ebook 1342: https://www.gutenberg.org/ebooks/1342.txt.utf-8
# Processing ebook ID: 1438
# Using plain text for ebook 1438: https://www.gutenberg.org/ebooks/1438.txt.utf-8
# Processing ebook ID: 35163
# Using plain text for ebook 35163: https://www.gutenberg.org/ebooks/35163.txt.utf-8
# Processing ebook ID: 161
# Using plain text for ebook 161: https://www.gutenberg.org/ebooks/161.txt.utf-8
# Processing ebook ID: 121
# Using plain text for ebook 121: https://www.gutenberg.org/ebooks/121.txt.utf-8
# Processing ebook ID: 51150
# Using plain text for ebook 51150: https://www.gutenberg.org/ebooks/51150.txt.utf-8
# Processing ebook ID: 20686
# No downloadable content found for ebook 20686.
# Skipping ebook 20686 due to lack of content.
# Processing ebook ID: 36961
# Using plain text for ebook 36961: https://www.gutenberg.org/ebooks/36961.txt.utf-8
# Processing ebook ID: 2487
# Using plain text for ebook 2487: https://www.gutenberg.org/ebooks/2487.txt.utf-8
# Processing ebook ID: 1400
# Using plain text for ebook 1400: https://www.gutenberg.org/ebooks/1400.txt.utf-8
# Processing ebook ID: 75411
# Using plain text for ebook 75411: https://www.gutenberg.org/ebooks/75411.txt.utf-8
# Processing ebook ID: 883
# Using plain text for ebook 883: https://www.gutenberg.org/ebooks/883.txt.utf-8
# Processing ebook ID: 26272
# No downloadable content found for ebook 26272.
# Skipping ebook 26272 due to lack of content.
# Processing ebook ID: 2834
# Using plain text for ebook 2834: https://www.gutenberg.org/ebooks/2834.txt.utf-8
# Processing ebook ID: 2833
# Using plain text for ebook 2833: https://www.gutenberg.org/ebooks/2833.txt.utf-8
# Processing ebook ID: 4276
# Using plain text for ebook 4276: https://www.gutenberg.org/ebooks/4276.txt.utf-8
# Processing ebook ID: 38703
# Using plain text for ebook 38703: https://www.gutenberg.org/ebooks/38703.txt.utf-8
# Processing ebook ID: 23077
# No downloadable content found for ebook 23077.
# Skipping ebook 23077 due to lack of content.
# Processing ebook ID: 4392
# Using plain text for ebook 4392: https://www.gutenberg.org/ebooks/4392.txt.utf-8
# Processing ebook ID: 583
# Using plain text for ebook 583: https://www.gutenberg.org/ebooks/583.txt.utf-8
# Using plain text for ebook 145: https://www.gutenberg.org/ebooks/145.txt.utf-8
# Processing ebook ID: 42671
# Using plain text for ebook 42671: https://www.gutenberg.org/ebooks/42671.txt.utf-8
# Processing ebook ID: 4240
# Using plain text for ebook 4240: https://www.gutenberg.org/ebooks/4240.txt.utf-8
# Processing ebook ID: 2596
# Using plain text for ebook 2596: https://www.gutenberg.org/ebooks/2596.txt.utf-8
# Processing ebook ID: 5182
# Using plain text for ebook 5182: https://www.gutenberg.org/ebooks/5182.txt.utf-8
# Processing ebook ID: 20687
# No downloadable content found for ebook 20687.
# Skipping ebook 20687 due to lack of content.
# Processing ebook ID: 2906
# Using plain text for ebook 2906: https://www.gutenberg.org/ebooks/2906.txt.utf-8
# Processing ebook ID: 67173
# Using plain text for ebook 67173: https://www.gutenberg.org/ebooks/67173.txt.utf-8
# Processing ebook ID: 26252
# No downloadable content found for ebook 26252.
# Skipping ebook 26252 due to lack of content.
# Processing ebook ID: 5231
# Using plain text for ebook 5231: https://www.gutenberg.org/ebooks/5231.txt.utf-8
# Processing ebook ID: 71865
# Using plain text for ebook 71865: https://www.gutenberg.org/ebooks/71865.txt.utf-8
# Processing ebook ID: 9611
# Using plain text for ebook 9611: https://www.gutenberg.org/ebooks/9611.txt.utf-8
# Processing ebook ID: 766
# Using plain text for ebook 766: https://www.gutenberg.org/ebooks/766.txt.utf-8
# Processing ebook ID: 2641
# Using plain text for ebook 2641: https://www.gutenberg.org/ebooks/2641.txt.utf-8
# Processing ebook ID: 6688
# Using plain text for ebook 6688: https://www.gutenberg.org/ebooks/6688.txt.utf-8
# Processing ebook ID: 550
# Using plain text for ebook 550: https://www.gutenberg.org/ebooks/550.txt.utf-8
# Processing ebook ID: 26301
# No downloadable content found for ebook 26301.
# Skipping ebook 26301 due to lack of content.
# Processing ebook ID: 209
# Using plain text for ebook 209: https://www.gutenberg.org/ebooks/209.txt.utf-8
# Processing ebook ID: 696
# Using plain text for ebook 696: https://www.gutenberg.org/ebooks/696.txt.utf-8
# Processing ebook ID: 104
# Using plain text for ebook 104: https://www.gutenberg.org/ebooks/104.txt.utf-8
# Processing ebook ID: 458
# Using plain text for ebook 458: https://www.gutenberg.org/ebooks/458.txt.utf-8
# Processing ebook ID: 26264
# No downloadable content found for ebook 26264.
# Skipping ebook 26264 due to lack of content.
# Processing ebook ID: 37634
# Using plain text for ebook 37634: https://www.gutenberg.org/ebooks/37634.txt.utf-8
# Processing ebook ID: 5999
# Using plain text for ebook 5999: https://www.gutenberg.org/ebooks/5999.txt.utf-8
# Processing ebook ID: 805
# Using plain text for ebook 805: https://www.gutenberg.org/ebooks/805.txt.utf-8
# Processing ebook ID: 6593
# Using plain text for ebook 6593: https://www.gutenberg.org/ebooks/6593.txt.utf-8
# Processing ebook ID: 3760
# Using plain text for ebook 3760: https://www.gutenberg.org/ebooks/3760.txt.utf-8
# Processing ebook ID: 22452
# No downloadable content found for ebook 22452.
# Skipping ebook 22452 due to lack of content.
# Processing ebook ID: 4047
# Using plain text for ebook 46945: https://www.gutenberg.org/ebooks/46945.txt.utf-8
# Processing ebook ID: 5118
# Using plain text for ebook 5118: https://www.gutenberg.org/ebooks/5118.txt.utf-8
# Processing ebook ID: 52200
# Using plain text for ebook 52200: https://www.gutenberg.org/ebooks/52200.txt.utf-8
# Compilation complete. Corpus saved to combined_corpus.txt.

# %%
def count_tokens(text):
    # Tokenize by splitting on whitespace; for more advanced tokenization,
    # consider using libraries like nltk or spaCy.
    tokens = text.split()
    num_tokens = len(tokens)
    unique_tokens = set(tokens)
    num_unique_tokens = len(unique_tokens)
    return num_tokens, num_unique_tokens

if __name__ == "__main__":
    # Replace 'author_corpus.txt' with your text file path if needed.
    with open("combined_corpus.txt", "r", encoding="utf-8") as f:
        text = f.read()

    total_tokens, unique_tokens = count_tokens(text)
    print(f"Total tokens: {total_tokens}")
    print(f"Unique tokens: {unique_tokens}")
# Out:
# Total tokens: 25796632
# Unique tokens: 192233

# %% [markdown]
# # **Downloaded All Gutenberg Books (Not all actually)**

# %%
#!apt-get update
#!apt-get install libdb-dev
#!pip install gutenberg --use-deprecated=legacy-resolver
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libdb-dev is already the newest version (1:5.3.21~exp1ubuntu4).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# Requirement already satisfied: gutenberg in /usr/local/lib/python3.11/dist-packages (0.8.2)
# WARNING: Package 'Gutenberg' has an invalid Requires-Python: Invalid specifier: '>=2.7.*'
# Requirement already satisfied: SPARQLWrapper>=1.8.2 in /usr/local/lib/python3.11/dist-packages (from gutenberg) (2.0.0)
# Requirement already satisfied: bsddb3>=6.1.0 in /usr/local/lib/python3.11/dist-packages (from gutenberg) (6.2.9)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.11/dist-packages (from gutenberg) (1.0.0)
# Requirement already satisfied: pyparsing<3.0.0 in /usr/local/lib/python3.11/dist-packages (from gutenberg) (2.4.7)
# Requirement already satisfied: rdflib-sqlalchemy>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from gutenberg) (0.5.4)
# Requirement already satisfied: rdflib<5.0.0,>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from gutenberg) (4.2.2)
# Requirement already satisfied: requests>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from gutenberg) (2.32.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from gutenberg) (75.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from gutenberg) (1.17.0)
# Requirement already satisfied: SQLAlchemy<2.0.0,>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from rdflib-sqlalchemy>=0.3.8->gutenberg) (1.4.54)
# Requirement already satisfied: alembic>=0.8.8 in /usr/local/lib/python3.11/dist-packages (from rdflib-sqlalchemy>=0.3.8->gutenberg) (1.15.1)
# Requirement already satisfied: isodate in /usr/local/lib/python3.11/dist-packages (from rdflib<5.0.0,>=4.2.0->gutenberg) (0.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.5.1->gutenberg) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.5.1->gutenberg) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.5.1->gutenberg) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.5.1->gutenberg) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<2.0.0,>=1.1.4->rdflib-sqlalchemy>=0.3.8->gutenberg) (3.1.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic>=0.8.8->rdflib-sqlalchemy>=0.3.8->gutenberg) (1.3.9)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=0.8.8->rdflib-sqlalchemy>=0.3.8->gutenberg) (4.12.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=0.8.8->rdflib-sqlalchemy>=0.3.8->gutenberg) (3.0.2)
# Querying for all English eBooks from Gutenberg...
# Error querying eBooks: get_etexts() got an unexpected keyword argument 'language'

# %%
# !wget -w 2 -m -H "http://www.gutenberg.org/robot/harvest?filetypes[]=txt&langs[]=en"
# Out:
# Streaming output truncated to the last 5000 lines.
# Last-modified header missing -- time-stamps turned off.
# 2025-03-08 07:10:10 (192 MB/s) - ‘www.gutenberg.org/robot/harvest?offset=1169900&filetypes[]=txt&langs[]=en’ saved [13254]
#
# --2025-03-08 07:10:12--  https://www.gutenberg.org/robot/harvest?offset=1172704&filetypes[]=txt&langs[]=en
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.gutenberg.org/robot/harvest?offset=1172704&filetypes[]=txt&langs[]=en’
#
# www.gutenberg.org/r     [ <=>                ]  13.13K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-03-08 07:10:13 (143 MB/s) - ‘www.gutenberg.org/robot/harvest?offset=1172704&filetypes[]=txt&langs[]=en’ saved [13442]
#
# --2025-03-08 07:10:15--  https://www.gutenberg.org/robot/harvest?offset=1225129&filetypes[]=txt&langs[]=en
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.gutenberg.org/robot/harvest?offset=
0.txt (deflated 60%)
#   adding: content/gutenberg/1/1/1/1115/old/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11112/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11112/11112-h/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11112/11112-h/images/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11112/11112-0.txt (deflated 58%)
#   adding: content/gutenberg/1/1/1/1/11112/old/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11115/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11115/11115.txt (deflated 63%)
#   adding: content/gutenberg/1/1/1/1/11115/11115-h/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11115/11115-0.txt (deflated 63%)
#   adding: content/gutenberg/1/1/1/1/11115/11115-8.txt (deflated 63%)
#   adding: content/gutenberg/1/1/1/1/11115/old/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11111/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11111/11111-0.txt (deflated 64%)
#   adding: content/gutenberg/1/1/1/1/11111/11111-h/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11111/old/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11117/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11117/old/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11117/11117-0.txt (deflated 60%)
#   adding: content/gutenberg/1/1/1/1/11118/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11118/old/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11118/11118-0.txt (deflated 60%)
#   adding: content/gutenberg/1/1/1/1/11116/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11116/11116-h/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11116/11116-h/images/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11116/old/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11116/11116-0.txt (deflated 61%)
#   adding: content/gutenberg/1/1/1/1/11119/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11119/11119-h/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11119/11119-0.txt (deflated 61%)
#   adding: content/gutenberg/1/1/1/1/11119/old/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11113/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11113/11113-h/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11113/11113-0.txt (deflated 61%)
#   adding: content/gutenberg/1/1/1/1/11113/old/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11114/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11114/11114-h/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11114/old/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11114/11114-0.txt (deflated 65%)
#   adding: content/gutenberg/1/1/1/1/11110/ (stored 0%)
#   adding: content/gutenberg/1/1/1/1/11110/11110-0.txt (deflated 63%)
#   adding: content/gutenberg/1/1/1/1/11110/old/ (stored 0%)
#   adding: content/gutenberg/1/14/ (stored 0%)
#   adding: content/gutenberg/cache/ (stored 0%)
#   adding: content/gutenberg/du-sk.static (stored 0%)
#   adding: content/gutenberg/GUTINDEX.2004 (deflated 71%)
#   adding: content/gutenberg/GUTINDEX.2009 (deflated 69%)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import re
import requests
import zipfile
import io
import pandas as pd
from bs4 import BeautifulSoup

# ----- Configuration -----
# Path to your metadata CSV file
metadata_csv_path = "/content/gutenberg_metadata.csv"  # adjust as needed

# Directory where your harvest HTML files are stored
harvest_dir = "/content/www.gutenberg.org/robot"

# Directory where processed books will be saved
processed_dir = "/content/processed_books"
if not os.path.exists(processed_dir):
    os.makedirs(processed_dir)

# Base URL (for constructing full links)
base_url = "https://www.gutenberg.org/"

# ----- Load Metadata CSV -----
# Expecting columns like "Text#" (ebook ID), "Authors", "Subjects", "Title", etc.
metadata_df = pd.read_csv(metadata_csv_path).fillna("")
# Build a dictionary keyed by ebook ID (as string)
metadata_dict = {}
for idx, row in metadata_df.iterrows():
    ebook_id = str(row["Text#"]).strip()  # adjust column name if needed
    metadata_dict[ebook_id] = {
        "Authors": str(row.get("Authors", "")).strip(),
        "Subjects": str(row.get("Subjects", "")).strip(),
        "Title": str(row.get("Title", "")).strip()
    }

# ----- Functions to Process ZIP Files -----
def extract_book_id(zip_url):
    """
    Try to extract the ebook ID from the zip_url.
    For example, from '.../12370/12370-8.zip', extract '12370'.
    """
    # Look for a pattern of one or more digits appearing twice in the URL
    m = re.search(r'/(\d+)/\1', zip_url)
    if m:
        return m.group(1)
    # If not, try a simpler search for a block of digits
    m = re.search(r'/(\d+)', zip_url)
    if m:
        return m.group(1)
    return None

def download_and_process_zip(zip_url):
    print(f"Downloading ZIP: {zip_url}")
    try:
        response = requests.get(zip_url)
        response.raise_for_status()
    except Exception as e:
        print(f"Error downloading {zip_url}: {e}")
        return

    book_id = extract_book_id(zip_url)
    if not book_id:
        print("Could not extract ebook ID from URL:", zip_url)
        return

    # Create a folder for this ebook if it doesn't exist
    book_folder = os.path.join(processed_dir, book_id)
    if not os.path.exists(book_folder):
        os.makedirs(book_folder)

    # Get metadata for this book if available
    meta = metadata_dict.get(book_id, {})
    metadata_header = ""
    if meta:
        metadata_header = (
            f"[AUTHOR: {meta.get('Authors', 'Unknown') }]\n"
            f"[SUBJECTS: {meta.get('Subjects', 'None') }]\n"
            f"[TITLE: {meta.get('Title', 'Untitled') }]\n"
            f"[BOOK]\n"
        )

    try:
        with zipfile.ZipFile(io.BytesIO(response.content)) as z:
            # Process all files ending with .txt (case-insensitive)
            for zinfo in z.infolist():
                if zinfo.filename.lower().endswith(".txt"):
                    print(f"Extracting {zinfo.filename} for book {book_id}")
                    # Read the text content
                    try:
                        with z.open(zinfo) as file:
                            text_content = file.read().decode('utf-8', errors='replace')
                    except Exception as e:
                        print(f"Error reading {zinfo.filename} in {zip_url}: {e}")
                        continue

                    # Prepend metadata header if available, and append an end marker.
                    full_text = metadata_header + text_content + "\n[END BOOK]\n[CONTEXT: Repeat Author and Subjects]\n"
                    # Save the file with the same name inside the book folder.
                    output_file_path = os.path.join(book_folder, os.path.basename(zinfo.filename))
                    with open(output_file_path, "w", encoding="utf-8") as out_f:
                        out_f.write(full_text)
    except Exception as e:
        print(f"Error extracting ZIP {zip_url}: {e}")

# ----- Process Harvest HTML Files -----
# Walk through the harvest directory and process files that contain "harvest" in their filename.
for root, dirs, files in os.walk(harvest_dir):
    for file in files:
        if "harvest" in file.lower():
            file_path = os.path.join(root, file)
            print(f"Processing HTML file: {file_path}")
            with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
                html_content = f.read()
            soup = BeautifulSoup(html_content, "html.parser")
            zip_links = [a.get("href") for a in soup.find_all("a") if a.get("href") and a.get("href").lower().endswith(".zip")]
            print(f"Found {len(zip_links)} zip links in {file_path}")
            for link in zip_links:
                zip_url = link if link.startswith("http") else requests.compat.urljoin(base_url, link)
                download_and_process_zip(zip_url)

print("Processing complete. Check the 'processed_books' directory for processed texts.")
# Out:
# Processing HTML file: /content/www.gutenberg.org/robot/harvest?offset=3108822&filetypes[]=txt&langs[]=en
# Found 100 zip links in /content/www.gutenberg.org/robot/harvest?offset=3108822&filetypes[]=txt&langs[]=en
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/2/41826/41826-8.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/2/41826/41826-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/2/41826/41826-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/2/41826/41826.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/2/41826/41826.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/2/41826/41826.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/2/41827/41827-0.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/2/41827/41827-0.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/2/41827/41827-0.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/2/41827/41827-8.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/2/41827/41827-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/2/41827/41827-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/2/41827/41827.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/2/41827/41827.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/2/41827/41827.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/2/41829/41829-0.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/2/41829/41829-0.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/2/41829/41829-0.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/2/41829/41829-8.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/2/41829/41829-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/2/41829/41829-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/2/41829/41829.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/2/41829/41829.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/2/41829/41829.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41830/41830-8.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/3/41830/41830-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/3/41830/41830-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41830/41830.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/3/41830/41830.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/3/41830/41830.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41831/41831.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/3/41831/41831.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/3/41831/41831.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41832/41832-0.zip
# Extracting 41832-0.txt for book 41832
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41832/41832-8.zip
# Extracting 41832-8.txt for book 41832
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41832/41832.zip
# Extracting 41832.txt for book 41832
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41833/41833-8.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/3/41833/41833-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/3/41833/41833-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41833/41833.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/3/41833/41833.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/3/41833/41833.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41834/41834-8.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/3/41834/41834-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/3/41834/41834-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41834/41834.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/3/41834/41834.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/3/41834/41834.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41835/41835-8.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/3/41835/41835-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/3/41835/41835-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41835/41835.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/3/41835/41835.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/3/41835/41835.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41836/41836-8.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/3/41836/41836-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/3/41836/41836-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/41836/41836.zip
# Error downloading http://aleph.gutenberg.org/4/1/8/3/41836/41836.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/1/8/3/41836/41836.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/1/8/3/
# Downloading ZIP: http://aleph.gutenberg.org/3/7/4/3745/3745.zip
# Extracting 3745.txt for book 3745
# Downloading ZIP: http://aleph.gutenberg.org/3/7/4/3746/3746.zip
# Extracting 3746.txt for book 3746
# Downloading ZIP: http://aleph.gutenberg.org/3/7/5/3752/3752.zip
# Extracting 3752.txt for book 3752
# Downloading ZIP: http://aleph.gutenberg.org/3/7/5/3753/3753.zip
# Extracting 3753.txt for book 3753
# Downloading ZIP: http://aleph.gutenberg.org/3/7/5/3754/3754-8.zip
# Extracting 3754-8.txt for book 3754
# Downloading ZIP: http://aleph.gutenberg.org/3/7/5/3754/3754.zip
# Extracting 3754.txt for book 3754
# Downloading ZIP: http://aleph.gutenberg.org/3/7/5/3755/3755.zip
# Extracting 3755.txt for book 3755
# Downloading ZIP: http://aleph.gutenberg.org/3/7/5/3757/3757.zip
# Extracting 3757.txt for book 3757
# Downloading ZIP: http://aleph.gutenberg.org/3/7/5/3758/3758.zip
# Extracting 3758.txt for book 3758
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/0/28804/28804-8.zip
# Extracting 28804-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/0/28804/28804.zip
# Extracting 28804.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28812/28812-8.zip
# Extracting 28812-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28812/28812.zip
# Extracting 28812.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28813/28813-8.zip
# Extracting 28813-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28813/28813.zip
# Extracting 28813.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28814/28814-0.zip
# Extracting 28814-0.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28814/28814.zip
# Extracting 28814.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28815/28815-8.zip
# Extracting 28815-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28815/28815.zip
# Extracting 28815.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28816/28816-0.zip
# Extracting 28816-0.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28816/28816.zip
# Extracting 28816.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28817/28817-0.zip
# Extracting 28817-0.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28817/28817.zip
# Extracting 28817.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28818/28818-0.zip
# Extracting 28818-0.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28818/28818.zip
# Extracting 28818.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28819/28819-8.zip
# Extracting 28819-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/1/28819/28819.zip
# Extracting 28819.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/2/28820/28820-8.zip
# Extracting 28820-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/2/28820/28820.zip
# Extracting 28820.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/3/7/7/3770/3770.zip
# Extracting 3770.txt for book 7
# Downloading ZIP: http://aleph.gutenberg.org/3/7/7/3776/3776.zip
# Extracting 3776.txt for book 7
# Downloading ZIP: http://aleph.gutenberg.org/3/7/7/3778/3778.zip
# Extracting 3778.txt for book 7
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/0/28805/28805-8.zip
# Extracting 28805-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/0/28805/28805.zip
# Extracting 28805.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/2/28824/28824-0.zip
# Extracting 28824-0.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/2/28824/28824.zip
# Extracting 28824.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/2/28825/28825-0.zip
# Extracting 28825-0.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/2/28825/28825.zip
# Extracting 28825.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/2/28826/28826-0.zip
# Extracting 28826-0.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/2/28826/28826.zip
# Extracting 28826.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/3/28830/28830-0.zip
# Extracting 28830-0.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/3/28830/28830.zip
# Extracting 28830.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/3/28831/28831-8.zip
# Extracting 28831-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/3/28831/28831.zip
# Extracting 28831.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/3/28832/28832.zip
# Extracting 28832.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/3/28833/28833-8.zip
# Extracting 28833-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/3/28833/28833.zip
# Extracting 28833.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/3/28834/28834-0.zip
# Extracting 28834-0.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/3/28834/28834.zip
# Extracting 28834.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/3/28835/28835-0.zip
# Extracting 28835-0.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/3/28835/28835.zip
# Extracting 28835.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/4/28846/28846.zip
# Extracting 28846.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/4/28847/28847-8.zip
# Extracting 28847-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/4/28847/28847.zip
# Extracting 28847.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/4/28848/28848-8.zip
# Extracting 28848-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/4/28848/28848.zip
# Extracting 28848.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/4/28849/28849-8.zip
# Extracting 28849-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/4/28849/28849.zip
# Extracting 28849.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/5/28851/28851-8.zip
# Extracting 28851-8.txt for book 8
# Downloading ZIP: http://aleph.gutenberg.org/2/8/8/5/28851/28851.zip
# Extracting 28851.txt for book 8
# Processing HTML file: /content/www.gutenberg.org/robot/harvest?offset=12815497&filetypes[]=txt&langs[]=en
# Found 100 zip links in /content/www.gutenberg.org/robot/harvest?offset=12815497&filetypes[]=txt&langs[]=en
# Downloading ZIP: http://aleph.gutenberg.org/5/3/0/3/53033/53033-0.zip
# Error downloading http://aleph.gutenberg.org/5/3/0/3/53033/53033-0.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/5/3/0/3/53033/53033-0.zip
# Downloading ZIP: http://aleph.gutenberg.org/5/3/0/3/53034/53034.zip
# Error downloading http://aleph.gutenberg.org/5/3/0/3/53034/53034.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/5/3/0/3/53034/53034.zip
# Downloading ZIP: http://aleph.gutenberg.org/5/3/0/3/53036/53036-0.zip
# Error downloading http://aleph.gutenberg.org/5/3/0/3/53036/53036-0.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/5/3/0/3/53036/53036-0.zip
# Downloading ZIP: http://aleph.gutenberg.org/1/6/2/1623/1623-0.zip
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f9202a40ea5f> in <cell line: 0>()
#     118             for link in zip_links:
#     119                 zip_url = link if link.startswith("http") else requests.compat.urljoin(base_url, link)
# --> 120                 download_and_process_zip(zip_url)
#     121
#     122 print("Processing complete. Check the 'processed_books' directory for processed texts.")
#
# <ipython-input-14-f9202a40ea5f> in download_and_process_zip(zip_url)
#      54     print(f"Downloading ZIP: {zip_url}")
#      55     try:
# ---> 56         response = requests.get(zip_url)
#      57         response.raise_for_status()
#      58     except Exception as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#    1064         else:
#    1065             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1066                 data = self.read(amt=amt, decode_content=decode_content)
#    1067
#    1068                 if data:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     953                 return self._decoded_buffer.get(amt)
#     954
# --> 955         data = self._raw_read(amt)
#     956
#     957         flush_decoder = amt is None or (amt != 0 and not data)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in _raw_read(self, amt, read1)
#     877
#     878         with self._error_catcher():
# --> 879             data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880             if amt is not None and amt != 0 and not data:
#     881                 # Platform-specific: Buggy versions of Python.
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in _fp_read(self, amt, read1)
#     860         else:
#     861             # StringIO doesn't like amt=None
# --> 862             return self._fp.read(amt) if amt is not None else self._fp.read()
#     863
#     864     def _raw_read(
#
# /usr/lib/python3.11/http/client.py in read(self, amt)
#     471                 # clip the read to the "end of response"
#     472                 amt = self.length
# --> 473             s = self.fp.read(amt)
#     474             if not s and amt:
#     475                 # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import os
import re
import requests
import zipfile
import io
import pandas as pd
from bs4 import BeautifulSoup

# ----- Configuration -----
metadata_csv_path = "/content/gutenberg_metadata.csv"  # adjust as needed
harvest_dir = "/content/www.gutenberg.org/robot"
processed_dir = "/content/processed_books"
if not os.path.exists(processed_dir):
    os.makedirs(processed_dir)
base_url = "https://www.gutenberg.org/"

# ----- Load Metadata CSV -----
metadata_df = pd.read_csv(metadata_csv_path).fillna("")
metadata_dict = {}

# Helper function to extract a 4-digit year from a date string (if needed)
def extract_year(issued):
    issued = str(issued).strip()
    if issued:
        parts = issued.split("/")
        if parts and len(parts[-1]) == 4 and parts[-1].isdigit():
            return parts[-1]
        else:
            m = re.search(r'\b(\d{4})\b', issued)
            if m:
                return m.group(1)
    return "Unknown"

# Build metadata dictionary from CSV
for idx, row in metadata_df.iterrows():
    ebook_id = str(row["Text#"]).strip()  # adjust column name if needed
    metadata_dict[ebook_id] = {
        "Authors": str(row.get("Authors", "")).strip(),
        "Subjects": str(row.get("Subjects", "")).strip(),
        "Title": str(row.get("Title", "")).strip(),
        "YEAR": extract_year(row.get("Issued", "")),
        "LoCC": str(row.get("LoCC", "")).strip(),
        "Bookshelves": str(row.get("Bookshelves", "")).strip()
    }

# ----- Function to Extract Book ID from a ZIP URL -----
def extract_book_id(zip_url):
    """
    Extract the ebook ID from a zip_url.
    Assumes the URL has a folder with the book id followed by a file whose name starts with the same id,
    optionally with a suffix (like -8) before .zip.
    For example, from '.../10084/10084-8.zip' it extracts '10084'.
    """
    m = re.search(r'/(\d+)/\d+(?:-\d+)?\.zip$', zip_url)
    if m:
        return m.group(1)
    return None

# ----- Function to Download and Process ZIP Files -----
def download_and_process_zip(zip_url):
    print(f"Downloading ZIP: {zip_url}")
    try:
        response = requests.get(zip_url)
        response.raise_for_status()
    except Exception as e:
        print(f"Error downloading {zip_url}: {e}")
        return

    book_id = extract_book_id(zip_url)
    if not book_id:
        print("Could not extract ebook ID from URL:", zip_url)
        return

    book_folder = os.path.join(processed_dir, book_id)
    if not os.path.exists(book_folder):
        os.makedirs(book_folder)

    # Get CSV metadata (if available) for additional tags.
    meta = metadata_dict.get(book_id, {})

    try:
        with zipfile.ZipFile(io.BytesIO(response.content)) as z:
            for zinfo in z.infolist():
                if zinfo.filename.lower().endswith(".txt"):
                    print(f"Extracting {zinfo.filename} for book {book_id}")
                    try:
                        with z.open(zinfo) as file:
                            text_content = file.read().decode('utf-8', errors='replace')
                    except Exception as e:
                        print(f"Error reading {zinfo.filename} in {zip_url}: {e}")
                        continue

                    # --- Trim the Project Gutenberg header/footer ---
                    # Remove everything before the start marker and after the end marker.
                    start_match = re.search(r'\*\*\* START OF THIS PROJECT GUTENBERG EBOOK.*?\*\*\*',
                                            text_content, re.IGNORECASE | re.DOTALL)
                    end_match = re.search(r'\*\*\* END OF THIS PROJECT GUTENBERG EBOOK.*?\*\*\*',
                                          text_content, re.IGNORECASE | re.DOTALL)

                    if start_match and end_match:
                        header_text = text_content[:start_match.start()]
                        book_body = text_content[start_match.end():end_match.start()]
                    else:
                        header_text = text_content
                        book_body = text_content

                    # --- Extract fields from header_text using case-insensitive matching ---
                    # Note: We account for variations like "author:" or "Author" etc.
                    author_field = re.search(r'(?i)^\s*author\s*[:\-]?\s*(.+)$', header_text, re.MULTILINE)
                    release_date_field = re.search(r'(?i)^\s*release date\s*[:\-]?\s*(.+)$', header_text, re.MULTILINE)
                    ebook_id_field = re.search(r'\[\s*EBook\s*#\s*(\d+)\s*\]', header_text, re.IGNORECASE)

                    author_val = author_field.group(1).strip() if author_field else "Unknown"
                    release_date_val = release_date_field.group(1).strip() if release_date_field else "Unknown"
                    ebook_id_val = ebook_id_field.group(1).strip() if ebook_id_field else book_id

                    # Build a new metadata header from the parsed fields.
                    new_metadata_header = (
                        f"[AUTHOR: {author_val}]\n"
                        f"[RELEASE DATE: {release_date_val}]\n"
                        f"[EBOOK ID: {ebook_id_val}]\n"
                    )

                    # Append additional CSV metadata (excluding already parsed fields).
                    other_metadata = ""
                    if meta:
                        other_metadata = (
                            f"[TITLE: {meta.get('Title', 'Untitled')}]\n"
                            f"[SUBJECTS: {meta.get('Subjects', 'None')}]\n"
                            f"[LOCC: {meta.get('LoCC', 'Unknown')}]\n"
                            f"[BOOKSHELVES: {meta.get('Bookshelves', 'Unknown')}]\n"
                        )

                    final_metadata_header = new_metadata_header + other_metadata + "[BOOK]\n"

                    # Build the final text: new metadata header + trimmed book body.
                    final_text = final_metadata_header + book_body.strip() + "\n[END BOOK]\n[CONTEXT: Repeat Author and Subjects]\n"

                    output_file_path = os.path.join(book_folder, os.path.basename(zinfo.filename))
                    with open(output_file_path, "w", encoding="utf-8") as out_f:
                        out_f.write(final_text)
    except Exception as e:
        print(f"Error extracting ZIP {zip_url}: {e}")

# ----- Process Harvest HTML Files -----
for root, dirs, files in os.walk(harvest_dir):
    for file in files:
        if "harvest" in file.lower():
            file_path = os.path.join(root, file)
            print(f"Processing HTML file: {file_path}")
            with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
                html_content = f.read()
            soup = BeautifulSoup(html_content, "html.parser")
            zip_links = [a.get("href") for a in soup.find_all("a") if a.get("href") and a.get("href").lower().endswith(".zip")]
            print(f"Found {len(zip_links)} zip links in {file_path}")
            for link in zip_links:
                zip_url = link if link.startswith("http") else requests.compat.urljoin(base_url, link)
                download_and_process_zip(zip_url)

print("Processing complete. Check the 'processed_books' directory for processed texts.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Found 100 zip links in /content/www.gutenberg.org/robot/harvest?offset=3477853&filetypes[]=txt&langs[]=en
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43422/43422-8.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/2/43422/43422-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/2/43422/43422-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43422/43422.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/2/43422/43422.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/2/43422/43422.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43423/43423-8.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/2/43423/43423-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/2/43423/43423-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43423/43423.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/2/43423/43423.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/2/43423/43423.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43424/43424-8.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/2/43424/43424-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/2/43424/43424-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43424/43424.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/2/43424/43424.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/2/43424/43424.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43425/43425-8.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/2/43425/43425-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/2/43425/43425-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43425/43425.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/2/43425/43425.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/2/43425/43425.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43426/43426-8.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/2/43426/43426-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/2/43426/43426-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43426/43426.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/2/43426/43426.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/2/43426/43426.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43427/43427-8.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/2/43427/43427-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/2/43427/43427-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43427/43427.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/2/43427/43427.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/2/43427/43427.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/1/43417/43417-8.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/1/43417/43417-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/1/43417/43417-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/1/43417/43417.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/1/43417/43417.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/1/43417/43417.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43429/43429-0.zip
# Extracting 43429-0.txt for book 43429
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43429/43429-8.zip
# Extracting 43429-8.txt for book 43429
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/2/43429/43429.zip
# Extracting 43429.txt for book 43429
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/3/43431/43431-8.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/3/43431/43431-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/3/43431/43431-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/3/43431/43431.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/3/43431/43431.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/3/43431/43431.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/3/43433/43433-0.zip
# Extracting 43433-0.txt for book 43433
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/3/43433/43433-8.zip
# Extracting 43433-8.txt for book 43433
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/3/43433/43433.zip
# Extracting 43433.txt for book 43433
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/3/43434/43434-8.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/3/43434/43434-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/3/43434/43434-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/3/43434/43434.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/3/43434/43434.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/3/43434/43434.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/3/43435/43435-8.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/3/43435/43435-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/3/43435/43435-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/3/43435/43435.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/3/43435/43435.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/3/43435/43435.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/3/43437/43437-8.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/3/43437/43437-8.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/3/43437/43437-8.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4/3/43437/43437.zip
# Error downloading http://aleph.gutenberg.org/4/3/4/3/43437/43437.zip: 404 Client Error: Not Found for url: http://aleph.gutenberg.org/4/3/4/3/43437/43437.zip
# Downloading ZIP: http://aleph.gutenberg.org/4/3/4
# Downloading ZIP: http://aleph.gutenberg.org/6/0/4/6044/6044.zip
# Extracting 6044.txt for book 6044
# Downloading ZIP: http://aleph.gutenberg.org/6/3/2/6322/6322.zip
# Extracting 6322.txt for book 6322
# Downloading ZIP: http://aleph.gutenberg.org/6/3/7/6375/6375.zip
# Extracting 6375.txt for book 6375
# Downloading ZIP: http://aleph.gutenberg.org/6/5/9/6596/6596.zip
# Extracting 6596.txt for book 6596
# Processing HTML file: /content/www.gutenberg.org/robot/harvest?offset=919376&filetypes[]=txt&langs[]=en
# Found 100 zip links in /content/www.gutenberg.org/robot/harvest?offset=919376&filetypes[]=txt&langs[]=en
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/8/26989/26989.zip
# Extracting 26989.txt for book 26989
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/9/26990/26990-8.zip
# Extracting 26990-8.txt for book 26990
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/9/26990/26990.zip
# Extracting 26990.txt for book 26990
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/9/26991/26991-8.zip
# Extracting 26991-8.txt for book 26991
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/9/26991/26991.zip
# Extracting 26991.txt for book 26991
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/9/26992/26992-8.zip
# Extracting 26992-8.txt for book 26992
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/9/26992/26992.zip
# Extracting 26992.txt for book 26992
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/9/26993/26993-8.zip
# Extracting 26993-8.txt for book 26993
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/9/26993/26993.zip
# Extracting 26993.txt for book 26993
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/9/26994/26994-8.zip
# Extracting 26994-8.txt for book 26994
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/9/26994/26994.zip
# Extracting 26994.txt for book 26994
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/9/26995/26995-0.zip
# Extracting 26995-0.txt for book 26995
# Downloading ZIP: http://aleph.gutenberg.org/2/6/9/9/26995/26995.zip
# Extracting 26995.txt for book 26995
# Downloading ZIP: http://aleph.gutenberg.org/2/0/2/2027/2027.zip
# Extracting 2027.txt for book 2027
# Downloading ZIP: http://aleph.gutenberg.org/2/0/3/2039/2039-8.zip
# Extracting 2039-8.txt for book 2039
# Downloading ZIP: http://aleph.gutenberg.org/2/0/3/2039/2039.zip
# Extracting 2039.txt for book 2039
# Downloading ZIP: http://aleph.gutenberg.org/2/0/5/2050/2050.zip
# Extracting 2050.txt for book 2050
# Downloading ZIP: http://aleph.gutenberg.org/2/0/5/2058/2058.zip
# Extracting 2058.txt for book 2058
# Downloading ZIP: http://aleph.gutenberg.org/2/0/8/2089/2089.zip
# Extracting 2089.txt for book 2089
# Downloading ZIP: http://aleph.gutenberg.org/2/0/9/2090/2090-0.zip
# Extracting 2090-0.txt for book 2090
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/5/27050/27050-0.zip
# Extracting 27050-0.txt for book 27050
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/5/27050/27050-8.zip
# Extracting 27050-8.txt for book 27050
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/5/27051/27051.zip
# Extracting 27051.txt for book 27051
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/5/27052/27052.zip
# Extracting 27052.txt for book 27052
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/5/27053/27053.zip
# Extracting 27053.txt for book 27053
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/5/27055/27055-8.zip
# Extracting 27055-8.txt for book 27055
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/5/27055/27055.zip
# Extracting 27055.txt for book 27055
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/5/27056/27056-8.zip
# Extracting 27056-8.txt for book 27056
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/5/27056/27056.zip
# Extracting 27056.txt for book 27056
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/5/27057/27057.zip
# Extracting 27057.txt for book 27057
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/5/27058/27058-8.zip
# Extracting 27058-8.txt for book 27058
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/5/27058/27058.zip
# Extracting 27058.txt for book 27058
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/6/27061/27061-8.zip
# Extracting 27061-8.txt for book 27061
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/6/27061/27061.zip
# Extracting 27061.txt for book 27061
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/6/27063/27063-8.zip
# Extracting 27063-8.txt for book 27063
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/6/27063/27063.zip
# Extracting 27063.txt for book 27063
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/6/27065/27065.zip
# Extracting 27065.txt for book 27065
# Downloading ZIP: http://aleph.gutenberg.org/2/7/0/6/
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/5/28957/28957-8.zip
# Extracting 28957-8.txt for book 28957
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/5/28957/28957.zip
# Extracting 28957.txt for book 28957
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/5/28958/28958-8.zip
# Extracting 28958-8.txt for book 28958
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/5/28958/28958.zip
# Extracting 28958.txt for book 28958
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/6/28960/28960-8.zip
# Extracting 28960-8.txt for book 28960
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/6/28960/28960.zip
# Extracting 28960.txt for book 28960
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/6/28961/28961-8.zip
# Extracting 28961-8.txt for book 28961
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/6/28961/28961.zip
# Extracting 28961.txt for book 28961
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/6/28964/28964-0.zip
# Extracting 28964-0.txt for book 28964
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/6/28964/28964-8.zip
# Extracting 28964-8.txt for book 28964
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/6/28964/28964.zip
# Extracting 28964.txt for book 28964
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/6/28966/28966.zip
# Extracting 28966.txt for book 28966
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/7/28973/28973.zip
# Extracting 28973.txt for book 28973
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/7/28974/28974-8.zip
# Extracting 28974-8.txt for book 28974
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/7/28974/28974.zip
# Extracting 28974.txt for book 28974
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/7/28975/28975-8.zip
# Extracting 28975-8.txt for book 28975
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/7/28975/28975.zip
# Extracting 28975.txt for book 28975
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/7/28976/28976-8.zip
# Extracting 28976-8.txt for book 28976
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/7/28976/28976.zip
# Extracting 28976.txt for book 28976
# Downloading ZIP: http://aleph.gutenberg.org/3/8/0/3800/3800-8.zip
# Extracting 3800-8.txt for book 3800
# Downloading ZIP: http://aleph.gutenberg.org/3/8/0/3800/3800.zip
# Extracting 3800.txt for book 3800
# Downloading ZIP: http://aleph.gutenberg.org/3/8/0/3806/3806.zip
# Extracting 3806.txt for book 3806
# Downloading ZIP: http://aleph.gutenberg.org/3/8/1/3810/3810.zip
# Extracting 3810.txt for book 3810
# Downloading ZIP: http://aleph.gutenberg.org/3/8/1/3811/3811.zip
# Extracting 3811.txt for book 3811
# Downloading ZIP: http://aleph.gutenberg.org/3/8/1/3812/3812.zip
# Extracting 3812.txt for book 3812
# Downloading ZIP: http://aleph.gutenberg.org/3/8/1/3814/3814.zip
# Extracting 3814.txt for book 3814
# Downloading ZIP: http://aleph.gutenberg.org/3/8/1/3817/3817.zip
# Extracting 3817.txt for book 3817
# Downloading ZIP: http://aleph.gutenberg.org/3/8/2/3827/3827.zip
# Extracting 3827.txt for book 3827
# Downloading ZIP: http://aleph.gutenberg.org/3/8/2/3829/3829.zip
# Extracting 3829.txt for book 3829
# Downloading ZIP: http://aleph.gutenberg.org/3/8/3/3830/3830.zip
# Extracting 3830.txt for book 3830
# Downloading ZIP: http://aleph.gutenberg.org/3/8/3/3831/3831.zip
# Extracting 3831.txt for book 3831
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/7/28979/28979-8.zip
# Extracting 28979-8.txt for book 28979
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/7/28979/28979.zip
# Extracting 28979.txt for book 28979
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28980/28980-8.zip
# Extracting 28980-8.txt for book 28980
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28980/28980.zip
# Extracting 28980.txt for book 28980
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28982/28982-8.zip
# Extracting 28982-8.txt for book 28982
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28982/28982.zip
# Extracting 28982.txt for book 28982
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28983/28983-8.zip
# Extracting 28983-8.txt for book 28983
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28983/28983.zip
# Extracting 28983.txt for book 28983
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28984/28984-8.zip
# Extracting 28984-8.txt for book 28984
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28984/28984.zip
# Extracting 28984.txt for book 28984
# Downloading ZIP: http://aleph.gutenberg.org/5/7/2/5723/5723.zip
# Extracting 5723.txt for book 5723
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28981/28981-8.zip
# Extracting 28981-8.txt for book 28981
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28981/28981.zip
# Extracting 28981.txt for book 28981
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28985/28985-0.zip
# Extracting 28985-0.txt for book 28985
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28985/28985.zip
# Extracting 28985.txt for book 28985
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28986/28986-0.zip
# Extracting 28986-0.txt for book 28986
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28986/28986.zip
# Extracting 28986.txt for book 28986
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28987/28987-8.zip
# Extracting 28987-8.txt for book 28987
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28987/28987.zip
# Extracting 28987.txt for book 28987
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28988/28988.zip
# Extracting 28988.txt for book 28988
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28989/28989-8.zip
# Extracting 28989-8.txt for book 28989
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/8/28989/28989.zip
# Extracting 28989.txt for book 28989
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/9/28990/28990-8.zip
# Extracting 28990-8.txt for book 28990
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/9/28990/28990.zip
# Extracting 28990.txt for book 28990
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/9/28991/28991-8.zip
# Extracting 28991-8.txt for book 28991
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/9/28991/28991.zip
# Extracting 28991.txt for book 28991
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/9/28992/28992-8.zip
# Extracting 28992-8.txt for book 28992
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/9/28992/28992.zip
# Extracting 28992.txt for book 28992
# Downloading ZIP: http://aleph.gutenberg.org/2/8/9/9/28994/28994-0.zip
# Extracting 28994-0.txt for book 28994
# Downloading ZIP: http://aleph.gutenberg.org/2/9/0/0/29001/29001-8.zip
# Extracting 29001-8.txt for book 29001
# Downloading ZIP: http://aleph.gutenberg.org/2/9/0/0/29001/29001.zip
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-0c54232e0125> in <cell line: 0>()
#     156             for link in zip_links:
#     157                 zip_url = link if link.startswith("http") else requests.compat.urljoin(base_url, link)
# --> 158                 download_and_process_zip(zip_url)
#     159
#     160 print("Processing complete. Check the 'processed_books' directory for processed texts.")
#
# <ipython-input-17-0c54232e0125> in download_and_process_zip(zip_url)
#      61     print(f"Downloading ZIP: {zip_url}")
#      62     try:
# ---> 63         response = requests.get(zip_url)
#      64         response.raise_for_status()
#      65     except Exception as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#    1064         else:
#    1065             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1066                 data = self.read(amt=amt, decode_content=decode_content)
#    1067
#    1068                 if data:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     953                 return self._decoded_buffer.get(amt)
#     954
# --> 955         data = self._raw_read(amt)
#     956
#     957         flush_decoder = amt is None or (amt != 0 and not data)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in _raw_read(self, amt, read1)
#     877
#     878         with self._error_catcher():
# --> 879             data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880             if amt is not None and amt != 0 and not data:
#     881                 # Platform-specific: Buggy versions of Python.
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in _fp_read(self, amt, read1)
#     860         else:
#     861             # StringIO doesn't like amt=None
# --> 862             return self._fp.read(amt) if amt is not None else self._fp.read()
#     863
#     864     def _raw_read(
#
# /usr/lib/python3.11/http/client.py in read(self, amt)
#     471                 # clip the read to the "end of response"
#     472                 amt = self.length
# --> 473             s = self.fp.read(amt)
#     474             if not s and amt:
#     475                 # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# !zip -r /content/gutenberg.zip /content/processed_books
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/processed_books/58919/ (stored 0%)
#   adding: content/processed_books/58919/58919-0.txt (deflated 61%)
#   adding: content/processed_books/22849/ (stored 0%)
#   adding: content/processed_books/22849/22849-8.txt (deflated 62%)
#   adding: content/processed_books/22849/22849.txt (deflated 62%)
#   adding: content/processed_books/22176/ (stored 0%)
#   adding: content/processed_books/22176/22176-8.txt (deflated 62%)
#   adding: content/processed_books/22176/22176.txt (deflated 62%)
#   adding: content/processed_books/35003/ (stored 0%)
#   adding: content/processed_books/35003/35003-8.txt (deflated 60%)
#   adding: content/processed_books/35003/35003.txt (deflated 60%)
#   adding: content/processed_books/26482/ (stored 0%)
#   adding: content/processed_books/26482/26482-8.txt (deflated 62%)
#   adding: content/processed_books/26482/26482.txt (deflated 62%)
#   adding: content/processed_books/59155/ (stored 0%)
#   adding: content/processed_books/59155/59155-0.txt (deflated 58%)
#   adding: content/processed_books/59155/59155-8.txt (deflated 58%)
#   adding: content/processed_books/9852/ (stored 0%)
#   adding: content/processed_books/9852/9852-8.txt (deflated 62%)
#   adding: content/processed_books/9852/9852.txt (deflated 62%)
#   adding: content/processed_books/3317/ (stored 0%)
#   adding: content/processed_books/3317/3317-0.txt (deflated 62%)
#   adding: content/processed_books/3317/3317.txt (deflated 62%)
#   adding: content/processed_books/3317/3317-8.txt (deflated 62%)
#   adding: content/processed_books/24016/ (stored 0%)
#   adding: content/processed_books/24016/24016-0.txt (deflated 66%)
#   adding: content/processed_books/24016/24016-8.txt (deflated 67%)
#   adding: content/processed_books/24016/24016.txt (deflated 67%)
#   adding: content/processed_books/37501/ (stored 0%)
#   adding: content/processed_books/37501/37501-8.txt (deflated 60%)
#   adding: content/processed_books/37501/37501.txt (deflated 60%)
#   adding: content/processed_books/34817/ (stored 0%)
#   adding: content/processed_books/34817/34817-8.txt (deflated 62%)
#   adding: content/processed_books/34817/34817.txt (deflated 62%)
#   adding: content/processed_books/16322/ (stored 0%)
#   adding: content/processed_books/16322/16322-8.txt (deflated 62%)
#   adding: content/processed_books/16322/16322.txt (deflated 62%)
#   adding: content/processed_books/39110/ (stored 0%)
#   adding: content/processed_books/39110/39110.txt (deflated 69%)
#   adding: content/processed_books/23359/ (stored 0%)
#   adding: content/processed_books/23359/23359-0.txt (deflated 55%)
#   adding: content/processed_books/58243/ (stored 0%)
#   adding: content/processed_books/58243/58243-0.txt (deflated 62%)
#   adding: content/processed_books/22319/ (stored 0%)
#   adding: content/processed_books/22319/22319.txt (deflated 61%)
#   adding: content/processed_books/27226/ (stored 0%)
#   adding: content/processed_books/27226/27226-8.txt (deflated 60%)
#   adding: content/processed_books/27226/27226.txt (deflated 60%)
#   adding: content/processed_books/27226/27226-0.txt (deflated 60%)
#   adding: content/processed_books/8495/ (stored 0%)
#   adding: content/processed_books/8495/8495-8.txt (deflated 62%)
#   adding: content/processed_books/29934/ (stored 0%)
#   adding: content/processed_books/32017/ (stored 0%)
#   adding: content/processed_books/32017/32017.txt (deflated 63%)
#   adding: content/processed_books/32017/32017-8.txt (deflated 63%)
#   adding: content/processed_books/36035/ (stored 0%)
#   adding: content/processed_books/36035/36035-8.txt (deflated 60%)
#   adding: content/processed_books/36035/36035.txt (deflated 60%)
#   adding: content/processed_books/8370/ (stored 0%)
#   adding: content/processed_books/8370/8370.txt (deflated 57%)
#   adding: content/processed_books/3194/ (stored 0%)
#   adding: content/processed_books/3194/3194-0.txt (deflated 62%)
#   adding: content/processed_books/19717/ (stored 0%)
#   adding: content/processed_books/19717/19717.txt (deflated 62%)
#   adding: content/processed_books/19717/19717-8.txt (deflated 62%)
#   adding: content/processed_books/3308/ (stored 0%)
#   adding: content/processed_books/3308/3308.txt (deflated 63%)
#   adding: content/processed_books/2902/ (stored 0%)
#   adding: content/processed_books/2902/2902.txt (deflated 60%)
#   adding: content/processed_books/25540/ (stored 0%)
#   adding: content/processed_books/25540/25540-8.txt (deflated 60%)
#   adding: content/processed_books/25540/25540.txt (deflated 60%)
#   adding: content/processed_books/4040/ (stored 0%)
#   adding: content/processed_books/4040/4040.txt (deflated 61%)
#   adding: content/processed_books/13418/ (stored 0%)
#   adding: content/processed_books/13418/13418-8.txt (deflated 61%)
#   adding: content/processed_books/13418/13418.txt (deflated 61%)
#   adding: content/processed_books/25014/ (stored 0%)
#   adding: content/processed_books/25014/25014-8.txt (deflated 60%)
#   adding: content/processed_books/25014/25014.txt (deflated 60%)
#   adding: content/processed_books/36548/ (stored 0%)
#   adding: content/processed_books/36548/36548.txt (deflated 77%)
#   adding: content/processed_books/36548/36548-0.txt (deflated 64%)
#   adding: content/processed_books/36548/36548-8.txt (deflated 77%)
#   adding: content/processed_books/56365/ (stored 0%)
#   adding: content/processed_books/56365/56365-0.txt (deflated 65%)
#   adding: content/processed_books/33452/ (stored 0%)
#   adding: content/processed_books/33452/33452.txt (deflated 60%)
#   adding: content/processed_books/33452/33452-8.txt (deflated 60%)
#   adding: content/processed_books/33452/33452-0.txt (deflated 61%)
#   adding: content/processed_books/57287/ (stored 0%)
#   adding: content/processed_books/57287/57287-0.txt (deflated 59%)
#   adding: content/processed_books/35567/ (stored 0%)
#   adding: content/processed_books/35567/35567.txt (deflated 69%)
#   adding: content/processed_books/3965/ (stored 0%)
#   adding: content/processed_books/3965/3965.txt (deflated 61%)
#   adding: content/processed_books/14955/ (stored 0%)
#   adding: content/processed_books/14955/14955-8.txt (deflated 58%)
#   adding: content/processed_books/14955/14955.txt (deflated 58%)
#   adding: content/processed_books/6441/ (stored 0%)
#   adding: content/processed_books/6441/6441.txt (deflated 65%)
#   adding: content/processed_books/25030/ (stored 0%)
#   adding: content/processed_books/25030/25030-8.txt (deflated 60%)
#   adding: content/processed_books/25030/25030.txt (deflated 60%)
#   adding: content/processed_books/2729/ (stored 0%)
#   adding: content/processed_books/2729/2729-0.txt (deflated 60%)
#   adding: content/processed_books/8849/ (stored 0%)
#   adding: content/processed_books/8849/8849.txt (deflated 60%)
#   adding: content/processed_books/25303/ (stored 0%)
#   adding: content/processed_books/25303/25303-0.txt (deflated 57%)
#   adding: content/processed_books/32648/ (stored 0%)
#   adding: content/processed_books/32648/32648.txt (deflated 64%)
#   adding: content/processed_books/34234/ (stored 0%)
#   adding: content/processed_books/34234/34234.txt (deflated 59%)
#   adding: content/processed_books/34234/34234-8.txt (deflated 59%)
#   adding: content/processed_books/14882/ (stored 0%)
#   adding: content/processed_books/14882/14882.txt (deflated 63%)
#   adding: content/processed_books/35550/ (stored 0%)
#   adding: content/processed_books/35550/35550-8.txt (deflated 64%)
#   adding: content/processed_books/35550/35550.txt (deflated 64%)
#   adding: content/processed_books/25532/ (stored 0%)
#   adding: content/processed_books/25532/25532.txt (deflated 64%)
#   adding: content/processed_books/25532/25532-0.txt (deflated 63%)
#   adding: content/processed_books/25532/25532-8.txt (deflated 63%)
#   adding: content/processed_books/3083/ (stored 0%)
#   adding: content/processed_books/3083/3083-0.txt (deflated 61%)
#   adding: content/processed_books/7776/ (stored 0%)
#   adding: content/processed_books/7776/7776-8.txt (deflated 60%)
#   adding: content/processed_books/33659/ (stored 0%)
#   adding: content/processed_books/33659/33659.txt (deflated 64%)
#   adding: content/processed_books/9901/ (stored 0%)
#   adding: content/processed_books/9901/9901.txt (deflated 62%)
#   adding: content/processed_books/9901/9901-8.txt (deflated 62%)
#   adding: content/processed_books/9050/ (stored 0%)
#   adding: content/processed_books/9050/9050-8.txt (deflated 62%)
#   adding: content/processed_books/17358/ (stored 0%)
#   adding: content/processed_books/17358/17358-8.txt (deflated 62%)
#   adding: content/processed_books/17358/17358.txt (deflated 62%)
#   adding: content/processed_books/18751/ (stored 0%)
#   adding: content/processed_books/18751/18751-8.txt (deflated 68%)
#   adding: content/processed_books/36345/ (stored 0%)
#   adding: content/processed_books/36345/36345-8.txt (deflated 65%)
#   adding: content/processed_books/36345/36345.txt (deflated 65%)
#   adding: content/processed_books/17966/ (stored 0%)
#   adding: content/processed_books/17966/17966-8.txt (deflated 64%)
#   adding: content/processed_books/17966/17966.txt (deflated 64%)
#   adding: content/processed_books/25122/ (stored 0%)
#   adding: content/processed_books/25122/25122-8.txt (deflated 60%)
#   adding: content/processed_books/25122/25122.txt (deflated 60%)
#   adding: content/processed_books/8936/ (stored 0%)
#   adding: content/processed_books/8936/8936-8.txt (deflated 60%)
#   adding: content/processed_books/35358/ (stored 0%)
#   adding: content/processed_books/35358/35358.txt (deflated 62%)
#   adding: content/processed_books/35358/35358-8.txt (deflated 62%)
#   adding: content/processed_books/32900/ (stored 0%)
#   adding: content/processed_books/32900/32900.txt (deflated 60%)
#   adding: content/processed_books/595/ (stored 0%)
#   adding: content/processed_books/595/595.txt (deflated 57%)
#   adding: content/processed_books/8347/ (stored 0%)
#   adding: content/processed_books/8347/8347.txt (deflated 65%)
#   adding: content/processed_books/57307/ (stored 0%)
#   adding: content/processed_books/57307/57307-0.txt (deflated 62%)
#   adding: content/processed_books/7801/ (stored 0%)
#   adding: content/processed_books/7801/7801.txt (deflated 63%)
#   adding: content/processed_books/57548/ (stored 0%)
#   adding: content/processed_books/57548/57548-0.txt (deflated 65%)
#   adding: content/processed_books/58318/ (stored 0%)
#   adding: content/processed_books/58318/58318-8.txt (deflated 60%)
#   adding: content/processed_books/58318/58318-0.txt (deflated 60%)
#   adding: content/processed_books/17919/ (stored 0%)
#   adding: content/processed_books/17919/17919-8.txt (deflated 66%)
#   adding: content/processed_books/17919/17919.txt (deflated 66%)
#   adding: content/processed_books/57582/ (stored 0%)
#   adding: content/processed_books/57582/57582-0.txt (deflated 63%)
#   adding: content/processed_books/22021/ (stored 0%)
#   adding: content/processed_books/22021/22021-8.txt (deflated 63%)
#   adding: content/processed_books/22021/22021.txt (deflated 63%)
#   adding: content/processed_books/25737/ (stored 0%)
#   adding: content/processed_books/25737/25737-8.txt (deflated 65%)
#   adding: content/processed_books/25737/25737.txt (deflated 65%)
#   adding: content/processed_books/25720/ (stored 0%)
#   adding: content/processed_books/25720/25720.txt (deflated 57%)
#   adding: content/processed_books/25720/25720-0.txt (deflated 57%)
#   adding: content/processed_books/25720/25720-8.txt (deflated 57%)
#   adding: content/processed_books/6481/ (stored 0%)
#   adding: content/processed_books/6481/6481.txt (deflated 64%)
#   adding: content/processed_books/33927/ (stored 0%)
#   adding: content/processed_books/33927/33927-8.txt (deflated 60%)
#   adding: content/processed_books/33927/33927.txt (deflated 60%)
#   adding: content/processed_books/34184/ (stored 0%)
#   adding: content/processed_books/34184/34184.txt (deflated 70%)
#   adding: content/processed_books/34184/34184-8.txt (deflated 70%)
#   adding: content/processed_books/38287/ (stored 0%)
#   adding: content/processed_books/38287/38287-0.txt (deflated 59%)
#   adding: content/processed_books/38287/38287.txt (deflated 58%)
#   adding: content/processed_books/38287/38287-8.txt (deflated 58%)
#   adding: content/processed_books/56409/ (stored 0%)
#   adding: content/processed_books/56409/56409-0.txt (deflated 65%)
#   adding: content/processed_books/7960/ (stored 0%)
#   adding: content/processed_books/7960/7960-8.txt (deflated 62%)
#   adding: content/processed_books/32067/ (stored 0%)
#   adding: content/processed_books/32067/32067.txt (deflated 60%)
#   adding: content/processed_books/24218/ (stored 0%)
#   adding: content/processed_books/24218/24218.txt (deflated 62%)
#   adding: content/processed_books/24218/24218-8.txt (deflated 62%)
#   adding: content/processed_books/59318/ (stored 0%)
#   adding: content/processed_books/59318/59318.txt (deflated 63%)
#   adding: content/processed_books/53862/ (stored 0%)
#   adding: content/processed_books/53862/53862-0.txt (deflated 60%)
#   adding: content/processed_books/39593/ (stored 0%)
#   adding: content/processed_books/39593/39593.txt (deflated 60%)
#   adding: content/processed_books/39593/39593-8.txt (deflated 60%)
#   adding: content/processed_books/26484/ (stored 0%)
#   adding: content/processed_books/26484/26484.txt (deflated 60%)
#   adding: content/processed_books/26484/26484-8.txt (deflated 60%)
#   adding: content/processed_books/33481/ (stored 0%)
#   adding: content/processed_books/33481/33481.txt (deflated 63%)
#   adding: content/processed_books/33481/33481-8.txt (deflated 63%)
#   adding: content/processed_books/27521/ (stored 0%)
#   adding: content/processed_books/27521/27521-8.txt (deflated 62%)
#   adding: content/processed_books/27521/27521.txt (deflated 62%)
#   adding: content/processed_books/32696/ (stored 0%)
#   adding: content/processed_books/32696/32696.txt (deflated 62%)
#   adding: content/processed_books/39230/ (stored 0%)
#   adding: content/processed_books/39230/39230-8.txt (deflated 66%)
#   adding: content/processed_books/39230/39230.txt (deflated 66%)
#   adding: content/processed_books/7528/ (stored 0%)
#   adding: content/processed_books/7528/7528-0.txt (deflated 61%)
#   adding: content/processed_books/7528/7528-8.txt (deflated 61%)
#   adding: content/processed_books/35828/ (stored 0%)
#   adding: content/processed_books/35828/35828.txt (deflated 63%)
#   adding: content/processed_books/35828/35828-8.txt (deflated 63%)
#   adding: content/processed_books/56439/ (stored 0%)
#   adding: content/processed_books/56439/56439-0.txt (deflated 62%)
#   adding: content/processed_books/36541/ (stored 0%)
#   adding: content/processed_books/36541/36541.txt (deflated 63%)
#   adding: content/processed_books/36541/36541-8.txt (deflated 63%)
#   adding: content/processed_books/21932/ (stored 0%)
#   adding: content/processed_books/21932/21932-0.txt (deflated 62%)
#   adding: content/processed_books/33805/ (stored 0%)
#   adding: content/processed_books/33805/33805-8.txt (deflated 62%)
#   adding: content/processed_books/33805/33805.txt (deflated 62%)
#   adding: content/processed_books/6482/ (stored 0%)
#   adding: content/processed_books/6482/6482.txt (deflated 61%)
#   adding: content/processed_books/17047/ (stored 0%)
#   adding: content/processed_books/17047/17047.txt (deflated 61%)
#   adding: content/processed_books/17047/17047-8.txt (deflated 61%)
#   adding: content/processed_books/17147/ (stored 0%)
#   adding: content/processed_books/17147/17147-8.txt (deflated 64%)
#   adding: content/processed_books/17147/17147.txt (deflated 64%)
#   adding: content/processed_books/36410/ (stored 0%)
#   adding: content/processed_books/36410/36410.txt (deflated 62%)
#   adding: content/processed_books/36410/36410-8.txt (deflated 62%)
#   adding: content/processed_books/15275/ (stored 0%)
#   adding: content/processed_books/15275/15275.txt (deflated 63%)
#   adding: content/processed_books/15275/15275-8.txt (deflated 63%)
#   adding: content/processed_books/17667/ (stored 0%)
#   adding: content/processed_books/17667/17667.txt (deflated 62%)
#   adding: content/processed_books/7415/ (stored 0%)
#   adding: content/processed_books/7415/7415.txt (deflated 62%)
#   adding: content/processed_books/16007/ (stored 0%)
#   adding: content/processed_books/16007/16007-0.txt (deflated 62%)
#   adding: content/processed_books/34701/ (stored 0%)
#   adding: content/processed_books/34701/34701.txt (deflated 68%)
#   adding: content/processed_books/6941/ (stored 0%)
#   adding: content/processed_books/6941/6941-0.txt (deflated 61%)
#   adding: content/processed_books/23217/ (stored 0%)
#   adding: content/processed_books/23217/23217.txt (deflated 58%)
#   adding: content/processed_books/6115/ (stored 0%)
#   adding: content/processed_books/6115/6115-0.txt (deflated 62%)
#   adding: content/processed_books/6115/6115.txt (deflated 61%)
#   adding: content/processed_books/26652/ (stored 0%)
#   adding: content/processed_books/26652/26652.txt (deflated 62%)
#   adding: content/processed_books/31240/ (stored 0%)
#   adding: content/processed_books/31240/31240-8.txt (deflated 62%)
#   adding: content/processed_books/31240/31240.txt (deflated 62%)
#   adding: content/processed_books/19336/ (stored 0%)
#   adding: content/processed_books/19336/19336-8.txt (deflated 61%)
#   adding: content/processed_books/19336/19336.txt (deflated 61%)
#   adding: content/processed_books/19368/ (stored 0%)
#   adding: content/processed_books/19368/19368-0.txt (deflated 65%)
#   adding: content/processed_books/19368/19368.txt (deflated 65%)
#   adding: content/processed_books/6677/ (stored 0%)
#   adding: content/processed_books/6677/6677.txt (deflated 68%)
#   adding: content/processed_books/23996/ (stored 0%)
#   adding: content/processed_books/23996/23996-8.txt (deflated 61%)
#   adding: content/processed_books/23996/23996.txt (deflated 61%)
#   adding: content/processed_books/24889/ (stored 0%)
#   adding: content/processed_books/24889/24889.txt (deflated 59%)
#   adding: content/processed_books/24889/24889-8.txt (deflated 59%)
#   adding: content/processed_books/2505/ (stored 0%)
#   adding: content/processed_books/2505/2505.txt (deflated 62%)
#   adding: content/processed_books/2505/2505-8.txt (deflated 62%)
#   adding: content/processed_books/59273/ (stored 0%)
#   adding: content/processed_books/59273/59273-0.txt (deflated 63%)
#   adding: content/processed_books/31209/ (stored 0%)
#   adding: content/processed_books/31209/31209-8.txt (deflated 66%)
#   adding: content/processed_books/31209/31209.txt (deflated 66%)
#   adding: content/processed_books/31209/31209-0.txt (deflated 66%)
#   adding: content/processed_books/29493/ (stored 0%)
#   adding: content/processed_books/29493/29493.txt (deflated 60%)
#   adding: content/processed_books/7935/ (stored 0%)
#   adding: content/processed_books/7935/7935-0.txt (deflated 63%)
#   adding: content/processed_books/21120/ (stored 0%)
#   adding: content/processed_books/21120/21120.txt (deflated 61%)
#   adding: content/processed_books/1166/ (stored 0%)
#   adding: content/processed_books/1166/1166.txt (deflated 61%)
#   adding: content/processed_books/19411/ (stored 0%)
#   adding: content/processed_books/19411/19411-8.txt (deflated 63%)
#   adding: content/processed_books/19411/19411.txt (deflated 63%)
#   adding: content/processed_books/57156/ (stored 0%)
#   adding: content/processed_books/57156/57156-0.txt (deflated 72%)
#   adding: content/processed_books/29929/ (stored 0%)
#   adding: content/processed_books/29929/29929.txt (deflated 61%)
#   adding: content/processed_books/29929/29929-8.txt (deflated 61%)
#   adding: content/processed_books/28417/ (stored 0%)
#   adding: content/processed_books/28417/28417.txt (deflated 58%)
#   adding: content/processed_books/28417/28417-8.txt (deflated 58%)
#   adding: content/processed_books/24934/ (stored 0%)
#   adding: content/processed_books/24934/24934.txt (deflated 62%)
#   adding: content/processed_books/24934/24934-8.txt (deflated 62%)
#   adding: content/processed_books/4182/ (stored 0%)
#   adding: content/processed_books/4182/4182.txt (deflated 62%)
#   adding: content/processed_books/34763/ (stored 0%)
#   adding: content/processed_books/34763/34763-8.txt (deflated 63%)
#   adding: content/processed_books/34763/34763.txt (deflated 63%)
#   adding: content/processed_books/38375/ (stored 0%)
#   adding: content/processed_books/38375/38375-8.txt (deflated 61%)
#   adding: content/processed_books/38375/38375.txt (deflated 61%)
#   adding: content/processed_books/29106/ (stored 0%)
#   adding: content/processed_books/29106/29106-8.txt (deflated 62%)
#   adding: content/processed_books/29106/29106.txt (deflated 62%)
#   adding: content/processed_books/9259/ (stored 0%)
#   adding: content/processed_books/9259/9259-8.txt (deflated 62%)
#   adding: content/processed_books/9259/9259.txt (deflated 62%)
#   adding: content/processed_books/7988/ (stored 0%)
#   adding: content/processed_books/7988/7988-8.txt (deflated 61%)
#   adding: content/processed_books/1813/ (stored 0%)
#   adding: content/processed_books/1813/1813.txt (deflated 59%)
#   adding: content/processed_books/1813/1813-0.txt (deflated 60%)
#   adding: content/processed_books/28110/ (stored 0%)
#   adding: content/processed_books/28110/28110.txt (deflated 60%)
#   adding: content/processed_books/28110/28110-8.txt (deflated 60%)
#   adding: content/processed_books/3358/ (stored 0%)
#   adding: content/processed_books/3358/3358.txt (deflated 60%)
#   adding: content/processed_books/58504/ (stored 0%)
#   adding: content/processed_books/58504/58504-8.txt (deflated 60%)
#   adding: content/processed_books/18135/ (stored 0%)
#   adding: content/processed_books/18135/18135-8.txt (deflated 60%)
#   adding: content/processed_books/18135/18135.txt (deflated 60%)
#   adding: content/processed_books/8350/ (stored 0%)
#   adding: content/processed_books/8350/8350.txt (deflated 66%)
#   adding: content/processed_books/36831/ (stored 0%)
#   adding: content/processed_books/36831/36831.txt (deflated 58%)
#   adding: content/processed_books/36831/36831-8.txt (deflated 58%)
#   adding: content/processed_books/1836/ (stored 0%)
#   adding: content/processed_books/1836/1836.txt (deflated 62%)
#   adding: content/processed_books/21200/ (stored 0%)
#   adding: content/processed_books/21200/21200-0.txt (deflated 62%)
#   adding: content/processed_books/21200/21200-8.txt (deflated 62%)
#   adding: content/processed_books/21200/21200.txt (deflated 62%)
#   adding: content/processed_books/38197/ (stored 0%)
#   adding: content/processed_books/38197/38197.txt (deflated 64%)
#   adding: content/processed_books/25004/ (stored 0%)
#   adding: content/processed_books/25004/25004-8.txt (deflated 61%)
#   adding: content/processed_books/25004/25004.txt (deflated 61%)
#   adding: content/processed_books/57929/ (stored 0%)
#   adding: content/processed_books/57929/57929-0.txt (deflated 62%)
#   adding: content/processed_books/57551/ (stored 0%)
#   adding: content/processed_books/57551/57551-0.txt (deflated 63%)
#   adding: content/processed_books/9701/ (stored 0%)
#   adding: content/processed_books/9701/9701-0.txt (deflated 60%)
#   adding: content/processed_books/36333/ (stored 0%)
#   adding: content/processed_books/36333/36333-8.txt (deflated 62%)
#   adding: content/processed_books/36333/36333-0.txt (deflated 62%)
#   adding: content/processed_books/36333/36333.txt (deflated 62%)
#   adding: content/processed_books/57124/ (stored 0%)
#   adding: content/processed_books/57124/57124-0.txt (deflated 64%)
#   adding: content/processed_books/6588/ (stored 0%)
#   adding: content/processed_books/6588/6588-8.txt (deflated 63%)
#   adding: content/processed_books/8230/ (stored 0%)
#   adding: content/processed_books/8230/8230.txt (deflated 74%)
#   adding: content/processed_books/16808/ (stored 0%)
#   adding: content/processed_books/16808/16808.txt (deflated 61%)
#   adding: content/processed_books/16808/16808-8.txt (deflated 61%)
#   adding: content/processed_books/8607/ (stored 0%)
#   adding: content/processed_books/8607/8607.txt (deflated 62%)
#   adding: content/processed_books/25129/ (stored 0%)
#   adding: content/processed_books/25129/25129.txt (deflated 59%)
#   adding: content/processed_books/25129/25129-8.txt (deflated 59%)
#   adding: content/processed_books/57086/ (stored 0%)
#   adding: content/processed_books/57086/57086-0.txt (deflated 61%)
#   adding: content/processed_books/19809/ (stored 0%)
#   adding: content/processed_books/19809/19809.txt (deflated 56%)
#   adding: content/processed_books/36818/ (stored 0%)
#   adding: content/processed_books/36818/36818.txt (deflated 60%)
#   adding: content/processed_books/36818/36818-8.txt (deflated 60%)
#   adding: content/processed_books/8287/ (stored 0%)
#   adding: content/processed_books/8287/8287.txt (deflated 60%)
#   adding: content/processed_books/36415/ (stored 0%)
#   adding: content/processed_books/36415/36415.txt (deflated 60%)
#   adding: content/processed_books/31091/ (stored 0%)
#   adding: content/processed_books/31091/31091-8.txt (deflated 59%)
#   adding: content/processed_books/31091/31091.txt (deflated 59%)
#   adding: content/processed_books/24395/ (stored 0%)
#   adding: content/processed_books/24395/24395.txt (deflated 61%)
#   adding: content/processed_books/23476/ (stored 0%)
#   adding: content/processed_books/23476/23476.txt (deflated 65%)
#   adding: content/processed_books/33804/ (stored 0%)
#   adding: content/processed_books/33804/33804.txt (deflated 62%)
#   adding: content/processed_books/33804/33804-8.txt (deflated 62%)
#   adding: content/processed_books/33661/ (stored 0%)
#   adding: content/processed_books/33661/33661.txt (deflated 59%)
#   adding: content/processed_books/16775/ (stored 0%)
#   adding: content/processed_books/16775/16775.txt (deflated 63%)
#   adding: content/processed_books/16775/16775-8.txt (deflated 63%)
#   adding: content/processed_books/4986/ (stored 0%)
#   adding: content/processed_books/4986/4986-0.txt (deflated 65%)
#   adding: content/processed_books/7336/ (stored 0%)
#   adding: content/processed_books/7336/7336-8.txt (deflated 59%)
#   adding: content/processed_books/15414/ (stored 0%)
#   adding: content/processed_books/15414/15414-8.txt (deflated 61%)
#   adding: content/processed_books/15414/15414.txt (deflated 61%)
#   adding: content/processed_books/23320/ (stored 0%)
#   adding: content/processed_books/23320/23320-8.txt (deflated 67%)
#   adding: content/processed_books/23320/23320.txt (deflated 67%)
#   adding: content/processed_books/17587/ (stored 0%)
#   adding: content/processed_books/17587/17587.txt (deflated 62%)
#   adding: content/processed_books/17587/17587-8.txt (deflated 62%)
#   adding: content/processed_books/35359/ (stored 0%)
#   adding: content/processed_books/35359/35359.txt (deflated 61%)
#   adding: content/processed_books/58391/ (stored 0%)
#   adding: content/processed_books/58391/58391-0.txt (deflated 65%)
#   adding: content/processed_books/10342/ (stored 0%)
#   adding: content/processed_books/10342/10342.txt (deflated 63%)
#   adding: content/processed_books/10342/10342-8.txt (deflated 63%)
#   adding: content/processed_books/3113/ (stored 0%)
#   adding: content/processed_books/3113/3113.txt (deflated 60%)
#   adding: content/processed_books/59090/ (stored 0%)
#   adding: content/processed_books/59090/59090-0.txt (deflated 62%)
#   adding: content/processed_books/34830/ (stored 0%)
#   adding: content/processed_books/34830/34830.txt (deflated 62%)
#   adding: content/processed_books/33282/ (stored 0%)
#   adding: content/processed_books/33282/33282-8.txt (deflated 64%)
#   adding: content/processed_books/33282/33282.txt (deflated 64%)
#   adding: content/processed_books/3669/ (stored 0%)
#   adding: content/processed_books/3669/3669.txt (deflated 61%)
#   adding: content/processed_books/58870/ (stored 0%)
#   adding: content/processed_books/58870/58870-0.txt (deflated 63%)
#   adding: content/processed_books/8059/ (stored 0%)
#   adding: content/processed_books/8059/8059.txt (deflated 60%)
#   adding: content/processed_books/37529/ (stored 0%)
#   adding: content/processed_books/37529/37529.txt (deflated 53%)
#   adding: content/processed_books/33459/ (stored 0%)
#   adding: content/processed_books/33459/33459-8.txt (deflated 55%)
#   adding: content/processed_books/33459/33459.txt (deflated 55%)
#   adding: content/processed_books/59589/ (stored 0%)
#   adding: content/processed_books/59589/59589-0.txt (deflated 70%)
#   adding: content/processed_books/59589/59589-8.txt (deflated 70%)
#   adding: content/processed_books/58408/ (stored 0%)
#   adding: content/processed_books/58408/58408-0.txt (deflated 62%)
#   adding: content/processed_books/13957/ (stored 0%)
#   adding: content/processed_books/13957/13957.txt (deflated 61%)
#   adding: content/processed_books/58005/ (stored 0%)
#   adding: content/processed_books/58005/58005-0.txt (deflated 68%)
#   adding: content/processed_books/8844/ (stored 0%)
#   adding: content/processed_books/8844/8844.txt (deflated 57%)
#   adding: content/processed_books/2323/ (stored 0%)
#   adding: content/processed_books/2323/2323.txt (deflated 63%)
#   adding: content/processed_books/2323/2323-0.txt (deflated 63%)
#   adding: content/processed_books/3197/ (stored 0%)
#   adding: content/processed_books/3197/3197-0.txt (deflated 61%)
#   adding: content/processed_books/28951/ (stored 0%)
#   adding: content/processed_books/28951/28951.txt (deflated 62%)
#   adding: content/processed_books/28951/28951-8.txt (deflated 62%)
#   adding: content/processed_books/39733/ (stored 0%)
#   adding: content/processed_books/39733/39733-0.txt (deflated 63%)
#   adding: content/processed_books/39733/39733.txt (deflated 63%)
#   adding: content/processed_books/39733/39733-8.txt (deflated 63%)
#   adding: content/processed_books/22745/ (stored 0%)
#   adding: content/processed_books/22745/22745-8.txt (deflated 62%)
#   adding: content/processed_books/22745/22745.txt (deflated 62%)
#   adding: content/processed_books/33638/ (stored 0%)
#   adding: content/processed_books/33638/33638-8.txt (deflated 72%)
#   adding: content/processed_books/33638/33638.txt (deflated 72%)
#   adding: content/processed_books/11365/ (stored 0%)
#   adding: content/processed_books/11365/11365-8.txt (deflated 64%)
#   adding: content/processed_books/11365/11365.txt (deflated 64%)
#   adding: content/processed_books/28763/ (stored 0%)
#   adding: content/processed_books/28763/28763.txt (deflated 61%)
#   adding: content/processed_books/28763/28763-8.txt (deflated 61%)
#   adding: content/processed_books/1731/ (stored 0%)
#   adding: content/processed_books/1731/1731-0.txt (deflated 62%)
#   adding: content/processed_books/23330/ (stored 0%)
#   adding: content/processed_books/23330/23330-0.txt (deflated 58%)
#   adding: content/processed_books/2156/ (stored 0%)
#   adding: content/processed_books/2156/2156.txt (deflated 62%)
#   adding: content/processed_books/2156/2156-8.txt (deflated 62%)
#   adding: content/processed_books/5363/ (stored 0%)
#   adding: content/processed_books/5363/5363.txt (deflated 60%)
#   adding: content/processed_books/19824/ (stored 0%)
#   adding: content/processed_books/19824/19824-8.txt (deflated 60%)
#   adding: content/processed_books/19824/19824.txt (deflated 60%)
#   adding: content/processed_books/34477/ (stored 0%)
#   adding: content/processed_books/34477/34477.txt (deflated 64%)
#   adding: content/processed_books/34477/34477-8.txt (deflated 64%)
#   adding: content/processed_books/57045/ (stored 0%)
#   adding: content/processed_books/57045/57045-0.txt (deflated 60%)
#   adding: content/processed_books/38601/ (stored 0%)
#   adding: content/processed_books/38601/38601-8.txt (deflated 62%)
#   adding: content/processed_books/38601/38601.txt (deflated 62%)
#   adding: content/processed_books/4350/ (stored 0%)
#   adding: content/processed_books/4350/4350-8.txt (deflated 62%)
#   adding: content/processed_books/4350/4350.txt (deflated 62%)
#   adding: content/processed_books/36277/ (stored 0%)
#   adding: content/processed_books/36277/36277-8.txt (deflated 61%)
#   adding: content/processed_books/36277/36277.txt (deflated 61%)
#   adding: content/processed_books/17890/ (stored 0%)
#   adding: content/processed_books/17890/17890-8.txt (deflated 61%)
#   adding: content/processed_books/17890/17890.txt (deflated 61%)
#   adding: content/processed_books/17574/ (stored 0%)
#   adding: content/processed_books/17574/17574.txt (deflated 58%)
#   adding: content/processed_books/16432/ (stored 0%)
#   adding: content/processed_books/16432/16432.txt (deflated 62%)
#   adding: content/processed_books/16432/16432-8.txt (deflated 62%)
#   adding: content/processed_books/20447/ (stored 0%)
#   adding: content/processed_books/20447/20447.txt (deflated 64%)
#   adding: content/processed_books/17766/ (stored 0%)
#   adding: content/processed_books/17766/17766.txt (deflated 64%)
#   adding: content/processed_books/32249/ (stored 0%)
#   adding: content/processed_books/32249/32249.txt (deflated 63%)
#   adding: content/processed_books/32249/32249-8.txt (deflated 63%)
#   adding: content/processed_books/59579/ (stored 0%)
#   adding: content/processed_books/59579/59579.txt (deflated 61%)
#   adding: content/processed_books/59579/59579-8.txt (deflated 61%)
#   adding: content/processed_books/6914/ (stored 0%)
#   adding: content/processed_books/6914/6914.txt (deflated 61%)
#   adding: content/processed_books/22073/ (stored 0%)
#   adding: content/processed_books/22073/22073.txt (deflated 58%)
#   adding: content/processed_books/8930/ (stored 0%)
#   adding: content/processed_books/8930/8930-8.txt (deflated 56%)
#   adding: content/processed_books/35753/ (stored 0%)
#   adding: content/processed_books/35753/35753.txt (deflated 60%)
#   adding: content/processed_books/35753/35753-8.txt (deflated 60%)
#   adding: content/processed_books/59966/ (stored 0%)
#   adding: content/processed_books/59966/59966-0.txt (deflated 62%)
#   adding: content/processed_books/56391/ (stored 0%)
#   adding: content/processed_books/56391/56391-0.txt (deflated 68%)
#   adding: content/processed_books/30932/ (stored 0%)
#   adding: content/processed_books/30932/30932.txt (deflated 61%)
#   adding: content/processed_books/6622/ (stored 0%)
#   adding: content/processed_books/6622/6622.txt (deflated 62%)
#   adding: content/processed_books/36547/ (stored 0%)
#   adding: content/processed_books/36547/36547.txt (deflated 63%)
#   adding: content/processed_books/36547/36547-8.txt (deflated 63%)
#   adding: content/processed_books/35367/ (stored 0%)
#   adding: content/processed_books/35367/35367.txt (deflated 62%)
#   adding: content/processed_books/58456/ (stored 0%)
#   adding: content/processed_books/58456/58456-0.txt (deflated 60%)
#   adding: content/processed_books/4178/ (stored 0%)
#   adding: content/processed_books/4178/4178.txt (deflated 63%)
#   adding: content/processed_books/24207/ (stored 0%)
#   adding: content/processed_books/24207/24207-8.txt (deflated 57%)
#   adding: content/processed_books/24207/24207.txt (deflated 57%)
#   adding: content/processed_books/21905/ (stored 0%)
#   adding: content/processed_books/21905/21905.txt (deflated 64%)
#   adding: content/processed_books/14869/ (stored 0%)
#   adding: content/processed_books/14869/14869-8.txt (deflated 65%)
#   adding: content/processed_books/14869/14869.txt (deflated 65%)
#   adding: content/processed_books/15749/ (stored 0%)
#   adding: content/processed_books/15749/15749-8.txt (deflated 63%)
#   adding: content/processed_books/15749/15749.txt (deflated 63%)
#   adding: content/processed_books/22285/ (stored 0%)
#   adding: content/processed_books/22285/22285-8.txt (deflated 61%)
#   adding: content/processed_books/22285/22285.txt (deflated 61%)
#   adding: content/processed_books/793/ (stored 0%)
#   adding: content/processed_books/793/793.txt (deflated 65%)
#   adding: content/processed_books/24993/ (stored 0%)
#   adding: content/processed_books/24993/24993.txt (deflated 67%)
#   adding: content/processed_books/17928/ (stored 0%)
#   adding: content/processed_books/17928/17928.txt (deflated 59%)
#   adding: content/processed_books/17928/17928-8.txt (deflated 59%)
#   adding: content/processed_books/17928/17928-0.txt (deflated 58%)
#   adding: content/processed_books/33629/ (stored 0%)
#   adding: content/processed_books/33629/33629.txt (deflated 62%)
#   adding: content/processed_books/27551/ (stored 0%)
#   adding: content/processed_books/27551/27551-8.txt (deflated 65%)
#   adding: content/processed_books/27551/27551.txt (deflated 65%)
#   adding: content/processed_books/31621/ (stored 0%)
#   adding: content/processed_books/31621/31621-8.txt (deflated 63%)
#   adding: content/processed_books/31621/31621.txt (deflated 63%)
#   adding: content/processed_books/17178/ (stored 0%)
#   adding: content/processed_books/17178/17178.txt (deflated 62%)
#   adding: content/processed_books/54662/ (stored 0%)
#   adding: content/processed_books/54662/54662-0.txt (deflated 62%)
#   adding: content/processed_books/57081/ (stored 0%)
#   adding: content/processed_books/57081/57081-0.txt (deflated 65%)
#   adding: content/processed_books/39351/ (stored 0%)
#   adding: content/processed_books/39351/39351-8.txt (deflated 54%)
#   adding: content/processed_books/39351/39351.txt (deflated 55%)
#   adding: content/processed_books/34237/ (stored 0%)
#   adding: content/processed_books/34237/34237-8.txt (deflated 63%)
#   adding: content/processed_books/34237/34237.txt (deflated 64%)
#   adding: content/processed_books/31762/ (stored 0%)
#   adding: content/processed_books/31762/31762-8.txt (deflated 56%)
#   adding: content/processed_books/31762/31762.txt (deflated 56%)
#   adding: content/processed_books/38173/ (stored 0%)
#   adding: content/processed_books/38173/38173.txt (deflated 65%)
#   adding: content/processed_books/38173/38173-8.txt (deflated 65%)
#   adding: content/processed_books/18989/ (stored 0%)
#   adding: content/processed_books/18989/18989-8.txt (deflated 61%)
#   adding: content/processed_books/18989/18989.txt (deflated 61%)
#   adding: content/processed_books/9311/ (stored 0%)
#   adding: content/processed_books/9311/9311-8.txt (deflated 62%)
#   adding: content/processed_books/9311/9311.txt (deflated 62%)
#   adding: content/processed_books/9311/9311-0.txt (deflated 62%)
#   adding: content/processed_books/57018/ (stored 0%)
#   adding: content/processed_books/57018/57018-0.txt (deflated 61%)
#   adding: content/processed_books/10873/ (stored 0%)
#   adding: content/processed_books/10873/10873.txt (deflated 61%)
#   adding: content/processed_books/410/ (stored 0%)
#   adding: content/processed_books/410/410.txt (deflated 60%)
#   adding: content/processed_books/5760/ (stored 0%)
#   adding: content/processed_books/5760/5760-8.txt (deflated 58%)
#   adding: content/processed_books/17987/ (stored 0%)
#   adding: content/processed_books/17987/17987.txt (deflated 62%)
#   adding: content/processed_books/1855/ (stored 0%)
#   adding: content/processed_books/1855/1855-0.txt (deflated 60%)
#   adding: content/processed_books/59171/ (stored 0%)
#   adding: content/processed_books/59171/59171-0.txt (deflated 62%)
#   adding: content/processed_books/2656/ (stored 0%)
#   adding: content/processed_books/2656/2656.txt (deflated 67%)
#   adding: content/processed_books/25511/ (stored 0%)
#   adding: content/processed_books/25511/25511.txt (deflated 63%)
#   adding: content/processed_books/25511/25511-0.txt (deflated 64%)
#   adding: content/processed_books/25511/25511-8.txt (deflated 63%)
#   adding: content/processed_books/33072/ (stored 0%)
#   adding: content/processed_books/33072/33072.txt (deflated 56%)
#   adding: content/processed_books/33072/33072-8.txt (deflated 56%)
#   adding: content/processed_books/3532/ (stored 0%)
#   adding: content/processed_books/3532/3532.txt (deflated 61%)
#   adding: content/processed_books/5994/ (stored 0%)
#   adding: content/processed_books/5994/5994.txt (deflated 60%)
#   adding: content/processed_books/5691/ (stored 0%)
#   adding: content/processed_books/5691/5691.txt (deflated 60%)
#   adding: content/processed_books/2176/ (stored 0%)
#   adding: content/processed_books/2176/2176.txt (deflated 64%)
#   adding: content/processed_books/6636/ (stored 0%)
#   adding: content/processed_books/6636/6636.txt (deflated 60%)
#   adding: content/processed_books/38429/ (stored 0%)
#   adding: content/processed_books/38429/38429.txt (deflated 63%)
#   adding: content/processed_books/17041/ (stored 0%)
#   adding: content/processed_books/17041/17041.txt (deflated 63%)
#   adding: content/processed_books/17041/17041-8.txt (deflated 63%)
#   adding: content/processed_books/8928/ (stored 0%)
#   adding: content/processed_books/8928/8928-8.txt (deflated 64%)
#   adding: content/processed_books/30887/ (stored 0%)
#   adding: content/processed_books/30887/30887.txt (deflated 59%)
#   adding: content/processed_books/30887/30887-0.txt (deflated 59%)
#   adding: content/processed_books/58538/ (stored 0%)
#   adding: content/processed_books/58538/58538-0.txt (deflated 62%)
#   adding: content/processed_books/27477/ (stored 0%)
#   adding: content/processed_books/27477/27477.txt (deflated 65%)
#   adding: content/processed_books/27477/27477-8.txt (deflated 65%)
#   adding: content/processed_books/32213/ (stored 0%)
#   adding: content/processed_books/32213/32213.txt (deflated 57%)
#   adding: content/processed_books/23574/ (stored 0%)
#   adding: content/processed_books/23574/23574.txt (deflated 63%)
#   adding: content/processed_books/23574/23574-8.txt (deflated 63%)
#   adding: content/processed_books/3551/ (stored 0%)
#   adding: content/processed_books/3551/3551.txt (deflated 62%)
#   adding: content/processed_books/3551/3551-8.txt (deflated 62%)
#   adding: content/processed_books/5307/ (stored 0%)
#   adding: content/processed_books/5307/5307.txt (deflated 61%)
#   adding: content/processed_books/29422/ (stored 0%)
#   adding: content/processed_books/29422/29422-8.txt (deflated 64%)
#   adding: content/processed_books/29422/29422.txt (deflated 64%)
#   adding: content/processed_books/58228/ (stored 0%)
#   adding: content/processed_books/58228/58228.txt (deflated 64%)
#   adding: content/processed_books/28742/ (stored 0%)
#   adding: content/processed_books/28742/28742-8.txt (deflated 62%)
#   adding: content/processed_books/28742/28742.txt (deflated 62%)
#   adding: content/processed_books/7815/ (stored 0%)
#   adding: content/processed_books/7815/7815-0.txt (deflated 61%)
#   adding: content/processed_books/30841/ (stored 0%)
#   adding: content/processed_books/30841/30841-8.txt (deflated 64%)
#   adding: content/processed_books/30841/30841.txt (deflated 64%)
#   adding: content/processed_books/38469/ (stored 0%)
#   adding: content/processed_books/38469/38469-8.txt (deflated 63%)
#   adding: content/processed_books/38469/38469.txt (deflated 63%)
#   adding: content/processed_books/2987/ (stored 0%)
#   adding: content/processed_books/2987/2987.txt (deflated 61%)
#   adding: content/processed_books/59106/ (stored 0%)
#   adding: content/processed_books/59106/59106-0.txt (deflated 65%)
#   adding: content/processed_books/36027/ (stored 0%)
#   adding: content/processed_books/36027/36027.txt (deflated 62%)
#   adding: content/processed_books/1819/ (stored 0%)
#   adding: content/processed_books/1819/1819-0.txt (deflated 57%)
#   adding: content/processed_books/39904/ (stored 0%)
#   adding: content/processed_books/39904/39904-8.txt (deflated 65%)
#   adding: content/processed_books/39904/39904.txt (deflated 65%)
#   adding: content/processed_books/6237/ (stored 0%)
#   adding: content/processed_books/6237/6237.txt (deflated 61%)
#   adding: content/processed_books/58255/ (stored 0%)
#   adding: content/processed_books/58255/58255-0.txt (deflated 64%)
#   adding: content/processed_books/32533/ (stored 0%)
#   adding: content/processed_books/32533/32533.txt (deflated 65%)
#   adding: content/processed_books/32533/32533-8.txt (deflated 65%)
#   adding: content/processed_books/32227/ (stored 0%)
#   adding: content/processed_books/32227/32227.txt (deflated 61%)
#   adding: content/processed_books/32227/32227-8.txt (deflated 61%)
#   adding: content/processed_books/34832/ (stored 0%)
#   adding: content/processed_books/34832/34832-8.txt (deflated 63%)
#   adding: content/processed_books/34832/34832.txt (deflated 63%)
#   adding: content/processed_books/59610/ (stored 0%)
#   adding: content/processed_books/59610/59610-0.txt (deflated 53%)
#   adding: content/processed_books/32883/ (stored 0%)
#   adding: content/processed_books/32883/32883-8.txt (deflated 64%)
#   adding: content/processed_books/32883/32883.txt (deflated 64%)
#   adding: content/processed_books/32883/32883-0.txt (deflated 64%)
#   adding: content/processed_books/21969/ (stored 0%)
#   adding: content/processed_books/21969/21969-0.txt (deflated 62%)
#   adding: content/processed_books/29152/ (stored 0%)
#   adding: content/processed_books/29152/29152.txt (deflated 69%)
#   adding: content/processed_books/15330/ (stored 0%)
#   adding: content/processed_books/15330/15330-8.txt (deflated 58%)
#   adding: content/processed_books/15330/15330.txt (deflated 58%)
#   adding: content/processed_books/5014/ (stored 0%)
#   adding: content/processed_books/5014/5014.txt (deflated 67%)
#   adding: content/processed_books/38060/ (stored 0%)
#   adding: content/processed_books/38060/38060.txt (deflated 61%)
#   adding: content/processed_books/38060/38060-8.txt (deflated 61%)
#   adding: content/processed_books/39196/ (stored 0%)
#   adding: content/processed_books/39196/39196-8.txt (deflated 61%)
#   adding: content/processed_books/39196/39196.txt (deflated 61%)
#   adding: content/processed_books/39196/39196-0.txt (deflated 61%)
# ...
#   adding: content/processed_books/3658/3658.txt (deflated 62%)
#   adding: content/processed_books/20296/ (stored 0%)
#   adding: content/processed_books/20296/20296.txt (deflated 62%)
#   adding: content/processed_books/20296/20296-8.txt (deflated 61%)
#   adding: content/processed_books/58915/ (stored 0%)
#   adding: content/processed_books/58915/58915-0.txt (deflated 66%)
#   adding: content/processed_books/6769/ (stored 0%)
#   adding: content/processed_books/6769/6769-0.txt (deflated 63%)
#   adding: content/processed_books/35845/ (stored 0%)
#   adding: content/processed_books/35845/35845.txt (deflated 61%)
#   adding: content/processed_books/35845/35845-8.txt (deflated 61%)
#   adding: content/processed_books/58542/ (stored 0%)
#   adding: content/processed_books/58542/58542-0.txt (deflated 62%)
#   adding: content/processed_books/641/ (stored 0%)
#   adding: content/processed_books/641/641-0.txt (deflated 64%)
#   adding: content/processed_books/29473/ (stored 0%)
#   adding: content/processed_books/29473/29473-8.txt (deflated 61%)
#   adding: content/processed_books/38750/ (stored 0%)
#   adding: content/processed_books/38750/38750.txt (deflated 64%)
#   adding: content/processed_books/38750/38750-8.txt (deflated 64%)
#   adding: content/processed_books/36353/ (stored 0%)
#   adding: content/processed_books/36353/36353-8.txt (deflated 59%)
#   adding: content/processed_books/36353/36353.txt (deflated 60%)
#   adding: content/processed_books/37085/ (stored 0%)
#   adding: content/processed_books/37085/37085-8.txt (deflated 61%)
#   adding: content/processed_books/37085/37085.txt (deflated 61%)
#   adding: content/processed_books/18653/ (stored 0%)
#   adding: content/processed_books/18653/18653-8.txt (deflated 61%)
#   adding: content/processed_books/18653/18653.txt (deflated 61%)
#   adding: content/processed_books/32326/ (stored 0%)
#   adding: content/processed_books/32326/32326-8.txt (deflated 64%)
#   adding: content/processed_books/32326/32326.txt (deflated 64%)
#   adding: content/processed_books/21705/ (stored 0%)
#   adding: content/processed_books/21705/21705.txt (deflated 61%)
#   adding: content/processed_books/75/ (stored 0%)
#   adding: content/processed_books/75/75.txt (deflated 63%)
#   adding: content/processed_books/16658/ (stored 0%)
#   adding: content/processed_books/16658/16658.txt (deflated 63%)
#   adding: content/processed_books/16658/16658-8.txt (deflated 63%)
#   adding: content/processed_books/27700/ (stored 0%)
#   adding: content/processed_books/39284/39284.txt (deflated 60%)
#   adding: content/processed_books/39284/39284-8.txt (deflated 60%)
#   adding: content/processed_books/23316/ (stored 0%)
#   adding: content/processed_books/23316/23316.txt (deflated 53%)
#   adding: content/processed_books/31482/ (stored 0%)
#   adding: content/processed_books/31482/31482.txt (deflated 63%)
#   adding: content/processed_books/31482/31482-8.txt (deflated 63%)
#   adding: content/processed_books/31482/31482-0.txt (deflated 63%)
#   adding: content/processed_books/40201/ (stored 0%)
#   adding: content/processed_books/40201/40201-0.txt (deflated 63%)
#   adding: content/processed_books/52834/ (stored 0%)
#   adding: content/processed_books/52834/52834-0.txt (deflated 61%)
#   adding: content/processed_books/27860/ (stored 0%)
#   adding: content/processed_books/27860/27860-8.txt (deflated 61%)
#   adding: content/processed_books/27860/27860.txt (deflated 61%)
#   adding: content/processed_books/18170/ (stored 0%)
#   adding: content/processed_books/18170/18170.txt (deflated 64%)
#   adding: content/processed_books/17049/ (stored 0%)
#   adding: content/processed_books/17049/17049-8.txt (deflated 62%)
#   adding: content/processed_books/17049/17049.txt (deflated 62%)
#   adding: content/processed_books/27500/ (stored 0%)
#   adding: content/processed_books/27500/27500.txt (deflated 64%)
#   adding: content/processed_books/27500/27500-8.txt (deflated 64%)
#   adding: content/processed_books/8312/ (stored 0%)
#   adding: content/processed_books/8312/8312.txt (deflated 67%)
#   adding: content/processed_books/28986/ (stored 0%)
#   adding: content/processed_books/28986/28986.txt (deflated 63%)
#   adding: content/processed_books/28986/28986-0.txt (deflated 63%)
#   adding: content/processed_books/2589/ (stored 0%)
#   adding: content/processed_books/2589/2589.txt (deflated 55%)
#   adding: content/processed_books/36434/ (stored 0%)
#   adding: content/processed_books/36434/36434.txt (deflated 66%)
#   adding: content/processed_books/20450/ (stored 0%)
#   adding: content/processed_books/20450/20450.txt (deflated 61%)
#   adding: content/processed_books/20450/20450-8.txt (deflated 61%)
#   adding: content/processed_books/7525/ (stored 0%)
#   adding: content/processed_books/7525/7525-8.txt (deflated 59%)
#   adding: content/processed_books/5377/ (stored 0%)
#   adding: content/processed_books/5377/5377.txt (deflated 61%)
#   adding: content/processed_books/6246/ (stored 0%)
#   adding: content/processed_books/6246/6246.txt (deflated 61%)
#   adding: content/processed_books/25677/ (stored 0%)
#   adding: content/processed_books/25677/25677.txt (deflated 63%)
#   adding: content/processed_books/25677/25677-8.txt (deflated 63%)
#   adding: content/processed_books/10641/ (stored 0%)
#   adding: content/processed_books/10641/10641.txt (deflated 63%)
#   adding: content/processed_books/10641/10641-8.txt (deflated 63%)
#   adding: content/processed_books/15883/ (stored 0%)
#   adding: content/processed_books/15883/15883.txt (deflated 61%)
#   adding: content/processed_books/58322/ (stored 0%)
#   adding: content/processed_books/58322/58322-0.txt (deflated 63%)
#   adding: content/processed_books/37357/ (stored 0%)
#   adding: content/processed_books/37357/37357.txt (deflated 61%)
#   adding: content/processed_books/5152/ (stored 0%)
#   adding: content/processed_books/5152/5152.txt (deflated 64%)
#   adding: content/processed_books/19772/ (stored 0%)
#   adding: content/processed_books/19772/19772.txt (deflated 55%)
#   adding: content/processed_books/1032/ (stored 0%)
#   adding: content/processed_books/1032/1032.txt (deflated 61%)
#   adding: content/processed_books/1032/1032-0.txt (deflated 62%)
#   adding: content/processed_books/20426/ (stored 0%)
#   adding: content/processed_books/20426/20426-8.txt (deflated 65%)
#   adding: content/processed_books/20426/20426.txt (deflated 65%)
#   adding: content/processed_books/38201/ (stored 0%)
#   adding: content/processed_books/38201/38201-0.txt (deflated 59%)
#   adding: content/processed_books/38201/38201.txt (deflated 60%)
#   adding: content/processed_books/38201/38201-8.txt (deflated 60%)
#   adding: content/processed_books/374/ (stored 0%)
#   adding: content/processed_books/374/374.txt (deflated 61%)
#   adding: content/processed_books/5651/ (stored 0%)
#   adding: content/processed_books/5651/5651.txt (deflated 61%)
#   adding: content/processed_books/26728/ (stored 0%)
#   adding: content/processed_books/26728/26728.txt (deflated 63%)
#   adding: content/processed_books/26728/26728-8.txt (deflated 63%)
#   adding: content/processed_books/34751/ (stored 0%)
#   adding: content/processed_books/34751/34751-8.txt (deflated 60%)
#   adding: content/processed_books/34751/34751.txt (deflated 60%)
#   adding: content/processed_books/34436/ (stored 0%)
#   adding: content/processed_books/34436/34436-8.txt (deflated 61%)
#   adding: content/processed_books/34436/34436.txt (deflated 61%)
#   adding: content/processed_books/36713/ (stored 0%)
#   adding: content/processed_books/36713/36713-8.txt (deflated 61%)
#   adding: content/processed_books/36713/36713.txt (deflated 61%)
#   adding: content/processed_books/35007/ (stored 0%)
#   adding: content/processed_books/35007/35007-8.txt (deflated 62%)
#   adding: content/processed_books/35007/35007.txt (deflated 62%)
#   adding: content/processed_books/5080/ (stored 0%)
#   adding: content/processed_books/5080/5080.txt (deflated 61%)
#   adding: content/processed_books/5080/5080-8.txt (deflated 61%)
#   adding: content/processed_books/31223/ (stored 0%)
#   adding: content/processed_books/31223/31223.txt (deflated 60%)
#   adding: content/processed_books/23669/ (stored 0%)
#   adding: content/processed_books/23669/23669-8.txt (deflated 61%)
#   adding: content/processed_books/23669/23669.txt (deflated 61%)
#   adding: content/processed_books/7506/ (stored 0%)
#   adding: content/processed_books/7506/7506.txt (deflated 62%)
#   adding: content/processed_books/1462/ (stored 0%)
#   adding: content/processed_books/1462/1462.txt (deflated 57%)
#   adding: content/processed_books/18300/ (stored 0%)
#   adding: content/processed_books/18300/18300.txt (deflated 60%)
#   adding: content/processed_books/18300/18300-8.txt (deflated 60%)
#   adding: content/processed_books/7617/ (stored 0%)
#   adding: content/processed_books/7617/7617.txt (deflated 59%)
#   adding: content/processed_books/7447/ (stored 0%)
#   adding: content/processed_books/7447/7447-0.txt (deflated 60%)
#   adding: content/processed_books/7447/7447.txt (deflated 60%)
#   adding: content/processed_books/24263/ (stored 0%)
#   adding: content/processed_books/24263/24263-8.txt (deflated 63%)
#   adding: content/processed_books/24263/24263.txt (deflated 63%)
#   adding: content/processed_books/39221/ (stored 0%)
#   adding: content/processed_books/39221/39221-8.txt (deflated 63%)
#   adding: content/processed_books/39221/39221.txt (deflated 63%)
#   adding: content/processed_books/21812/ (stored 0%)
#   adding: content/processed_books/21812/21812.txt (deflated 63%)
#   adding: content/processed_books/1669/ (stored 0%)
#   adding: content/processed_books/1669/1669.txt (deflated 62%)
#   adding: content/processed_books/4536/ (stored 0%)
#   adding: content/processed_books/4536/4536.txt (deflated 61%)
#   adding: content/processed_books/23410/ (stored 0%)
#   adding: content/processed_books/23410/23410-0.txt (deflated 59%)
#   adding: content/processed_books/23410/23410-8.txt (deflated 58%)
#   adding: content/processed_books/23410/23410.txt (deflated 58%)
#   adding: content/processed_books/58302/ (stored 0%)
#   adding: content/processed_books/58302/58302-0.txt (deflated 60%)
#   adding: content/processed_books/4282/ (stored 0%)
#   adding: content/processed_books/4282/4282-8.txt (deflated 63%)
#   adding: content/processed_books/4282/4282.txt (deflated 63%)
#   adding: content/processed_books/57421/ (stored 0%)
#   adding: content/processed_books/57421/57421-0.txt (deflated 66%)
#   adding: content/processed_books/17374/ (stored 0%)
#   adding: content/processed_books/17374/17374.txt (deflated 57%)
#   adding: content/processed_books/57164/ (stored 0%)
#   adding: content/processed_books/57164/57164-8.txt (deflated 63%)
#   adding: content/processed_books/57164/57164.txt (deflated 63%)
#   adding: content/processed_books/24916/ (stored 0%)
#   adding: content/processed_books/24916/24916.txt (deflated 61%)
#   adding: content/processed_books/6422/ (stored 0%)
#   adding: content/processed_books/6422/6422.txt (deflated 64%)
#   adding: content/processed_books/24063/ (stored 0%)
#   adding: content/processed_books/24063/24063-8.txt (deflated 73%)
#   adding: content/processed_books/24063/24063.txt (deflated 73%)
#   adding: content/processed_books/3762/ (stored 0%)
#   adding: content/processed_books/3762/3762.txt (deflated 61%)
#   adding: content/processed_books/29574/ (stored 0%)
#   adding: content/processed_books/29574/29574.txt (deflated 60%)
#   adding: content/processed_books/29574/29574-8.txt (deflated 60%)
#   adding: content/processed_books/14970/ (stored 0%)
#   adding: content/processed_books/14970/14970-8.txt (deflated 61%)
#   adding: content/processed_books/14970/14970-0.txt (deflated 61%)
#   adding: content/processed_books/14970/14970.txt (deflated 61%)
#   adding: content/processed_books/36879/ (stored 0%)
#   adding: content/processed_books/36879/36879-8.txt (deflated 59%)
#   adding: content/processed_books/36879/36879.txt (deflated 59%)
#   adding: content/processed_books/15464/ (stored 0%)
#   adding: content/processed_books/15464/15464.txt (deflated 67%)
#   adding: content/processed_books/15464/15464-8.txt (deflated 67%)
#   adding: content/processed_books/5057/ (stored 0%)
#   adding: content/processed_books/5057/5057.txt (deflated 63%)
#   adding: content/processed_books/9815/ (stored 0%)
#   adding: content/processed_books/9815/9815.txt (deflated 61%)
#   adding: content/processed_books/9815/9815-8.txt (deflated 61%)
#   adding: content/processed_books/32505/ (stored 0%)
#   adding: content/processed_books/32505/32505.txt (deflated 68%)
#   adding: content/processed_books/32505/32505-8.txt (deflated 68%)
#   adding: content/processed_books/18660/ (stored 0%)
#   adding: content/processed_books/18660/18660-8.txt (deflated 61%)
#   adding: content/processed_books/18660/18660.txt (deflated 61%)
#   adding: content/processed_books/59287/ (stored 0%)
#   adding: content/processed_books/59287/59287.txt (deflated 58%)

# %%
from google.colab import files
files.download('/content/full_books_text.txt')

# %%
from datasets import load_dataset

# Load the dataset (you can choose a split, e.g., "train")
dataset = load_dataset("super_natural_instructions", split="train")

# Output file name
output_file = "super_natural_instructions_tagged.txt"

with open(output_file, "w", encoding="utf-8") as f:
    for example in dataset:
        # Extract fields. If a field is empty, we can output "None" or an empty string.
        instruction = example.get("instruction", "").strip() or "None"
        input_text = example.get("input", "").strip() or "None"
        output_text = example.get("output", "").strip() or "None"
        task_name = example.get("task_name", "").strip() or "None"

        # Write the formatted example to the file with tags.
        f.write(f"[INSTRUCTION: {instruction}]\n")
        f.write(f"[INPUT: {input_text}]\n")
        f.write(f"[OUTPUT: {output_text}]\n")
        f.write(f"[TASK: {task_name}]\n")
        f.write("[END EXAMPLE]\n\n")

print(f"Saved tagged dataset to {output_file}")

# %%
import os
import re
import polars as pl
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

# Function to recursively list all .txt files under a directory.
def get_txt_files(root_dir):
    file_paths = []
    for root, _, files in os.walk(root_dir):
        for file in files:
            if file.endswith(".txt"):
                file_paths.append(os.path.join(root, file))
    return file_paths

# Define a cleaning function to normalize the text.
def clean_text(text):
    # Replace multiple newlines with two newlines (preserving paragraph breaks)
    text = re.sub(r'\n\s*\n', '\n\n', text)
    # Replace multiple spaces with a single space
    text = re.sub(r' +', ' ', text)
    return text.strip()

# Function to read and clean a file.
def read_and_clean_file(fp):
    # Optionally, print the file being processed (note: output may be interleaved in parallel execution)
    # print(f"Processing {fp}")
    try:
        with open(fp, "r", encoding="utf8") as f:
            content = f.read()
        cleaned = clean_text(content)
        if not cleaned:
            print(f"Warning: {fp} appears empty after cleaning.")
        return cleaned
    except Exception as e:
        print(f"Error reading {fp}: {e}")
        return ""

# Set your absolute path to the processed books folder.
books_dir = "/content/processed_books"
if not os.path.exists(books_dir):
    print(f"Folder {books_dir} doesn't exist!")
else:
    print(f"Folder {books_dir} exists.")

# Discover all .txt files.
file_list = get_txt_files(books_dir)
print(f"Discovered {len(file_list)} text files in nested folders.")

# Create a Polars DataFrame with file paths and file names.
df = pl.DataFrame({
    "file_path": file_list,
    "file_name": [os.path.basename(fp) for fp in file_list]
})

# Ensure file_name is a string.
df = df.with_columns(pl.col("file_name").fill_null(""))

# Extract the book ID from filenames.
df = df.with_columns(
    pl.col("file_name").str.extract(r"^(\d+)(?:-[0-9]+)?\.txt$", 1).alias("book_id"),
    (~pl.col("file_name").str.contains("-")).alias("is_primary")
)

# Filter out any rows where book_id wasn't extracted.
df = df.filter(pl.col("book_id").is_not_null())
print("DataFrame after regex extraction:")
print(df)

# For each book_id, sort so that primary files come first, then take the first unique entry.
df_primary = df.sort("is_primary", descending=True).unique("book_id", keep="first")
print(f"Unique primary files: {df_primary.shape[0]}")

# Parallelize file reading with a ThreadPoolExecutor using tqdm for progress.
file_paths = df_primary["file_path"].to_list()
print("Reading and cleaning files in parallel...")

with ThreadPoolExecutor(max_workers=8) as executor:
    texts = list(tqdm(executor.map(read_and_clean_file, file_paths), total=len(file_paths)))

# Optionally, report how many files produced empty text.
num_empty = sum(1 for t in texts if not t)
print(f"{num_empty} out of {len(texts)} files produced empty text.")
# Out:
# Folder /content/processed_books exists.
# Discovered 26883 text files in nested folders.
# DataFrame after regex extraction:
# shape: (26_883, 4)
# ┌─────────────────────────────────┬─────────────┬─────────┬────────────┐
# │ file_path                       ┆ file_name   ┆ book_id ┆ is_primary │
# │ ---                             ┆ ---         ┆ ---     ┆ ---        │
# │ str                             ┆ str         ┆ str     ┆ bool       │
# ╞═════════════════════════════════╪═════════════╪═════════╪════════════╡
# │ /content/processed_books/31518… ┆ 31518.txt   ┆ 31518   ┆ true       │
# │ /content/processed_books/31518… ┆ 31518-8.txt ┆ 31518   ┆ false      │
# │ /content/processed_books/15416… ┆ 15416.txt   ┆ 15416   ┆ true       │
# │ /content/processed_books/22744… ┆ 22744-8.txt ┆ 22744   ┆ false      │
# │ /content/processed_books/22744… ┆ 22744.txt   ┆ 22744   ┆ true       │
# │ …                               ┆ …           ┆ …       ┆ …          │
# │ /content/processed_books/32505… ┆ 32505.txt   ┆ 32505   ┆ true       │
# │ /content/processed_books/32505… ┆ 32505-8.txt ┆ 32505   ┆ false      │
# │ /content/processed_books/18660… ┆ 18660-8.txt ┆ 18660   ┆ false      │
# │ /content/processed_books/18660… ┆ 18660.txt   ┆ 18660   ┆ true       │
# │ /content/processed_books/59287… ┆ 59287.txt   ┆ 59287   ┆ true       │
# └─────────────────────────────────┴─────────────┴─────────┴────────────┘
# Unique primary files: 16873
# Reading and cleaning files in parallel...
# 100%|██████████| 16873/16873 [06:51<00:00, 41.02it/s]
# 0 out of 16873 files produced empty text.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-412ed7f21ac4> in <cell line: 0>()
#      84
#      85 # Add the texts to the DataFrame.
# ---> 86 df_primary = df_primary.with_column(pl.Series("text", texts))
#      87
#      88 # Concatenate all book texts with a clear delimiter.
#
# AttributeError: 'DataFrame' object has no attribute 'with_column'

# %%
# Add the texts to the DataFrame.
df_primary = df_primary.with_columns(pl.Series("text", texts))

# Concatenate all book texts with a clear delimiter.
delimiter = "\n\n### NEW BOOK ###\n\n"
full_books_text = delimiter.join(df_primary["text"].to_list())

# Write the full books corpus to a file.
output_path = "full_books_text.txt"
with open(output_path, "w", encoding="utf8") as f:
    f.write(full_books_text)

print(f"Compilation complete! The full books corpus is saved as '{output_path}'.")
# Out:
# Compilation complete! The full books corpus is saved as 'full_books_text.txt'.

# %%
import polars as pl

# Lazily read the file as a CSV with one column ("line"), treating each line as a row.
df = pl.scan_csv(
    "/content/full_books_text.txt",
    has_header=False,
    new_columns=["line"],
    separator="\n",            # Use newline as the record separator
    ignore_errors=True,        # Skip rows that cause parsing errors
    infer_schema_length=10000, # Increase inference length for schema detection
    schema_overrides={"line": pl.Utf8},
    quote_char=None            # Disable quoting so no fields are interpreted as quoted
)

# Now, split each line into tokens (splitting on whitespace) and explode the tokens.
tokens_df = df.with_columns(
    pl.col("line").str.split(" ").alias("tokens")
).explode("tokens")

# Collect the first 100 tokens.
first_100_tokens = tokens_df.select("tokens").head(100).collect()["tokens"].to_list()

# Count the total number of tokens.
total_tokens = tokens_df.select(pl.count("tokens")).collect().item()

# Count the unique tokens.
unique_tokens = tokens_df.select(pl.col("tokens").n_unique()).collect().item()

print("First 100 tokens:")
print(" ".join(first_100_tokens))
print("\nToken counts:")
print("Total tokens:", total_tokens)
print("Unique tokens:", unique_tokens)
# Out:
# First 100 tokens:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-33c296adc075> in <cell line: 0>()
#      30
#      31 print("First 100 tokens:")
# ---> 32 print(" ".join(first_100_tokens))
#      33
#      34 # --- For counting tokens over the full file ---
#
# TypeError: sequence item 35: expected str instance, NoneType found

# %%
# !split -n 8 /content/full_books_text.txt /content/full_books_text_part_

# %%
# Collect in streaming mode to avoid memory spikes.
limited_tokens = tokens_df_limited.select("tokens").collect(streaming=True)["tokens"].to_list()

# In case the list has None values, filter them out.
limited_tokens = [token for token in limited_tokens if token is not None]

# Then take the first 100 tokens.
first_100_tokens = limited_tokens[:100]

print("First 100 tokens:")
print(" ".join(first_100_tokens))
# Out:
# First 100 tokens:
# [AUTHOR: Edward Everett Hale] [RELEASE DATE: September, 2005] [EBOOK ID: 8904] [TITLE: How to Do It] [SUBJECTS: Self-culture] [LOCC: BJ] [BOOKSHELVES: Browsing: How To...; Browsing: Philosophy & Ethics; Browsing: Psychiatry/Psychology] [BOOK] Produced by Distributed Proofreaders How To Do It. By Edward Everett Hale. Contents.  Chapter I. Introductory.--How We Met  Chapter II. How To Talk  Chapter III. Talk  Chapter IV. How To Write  Chapter V. How To Read. I.  Chapter VI. How To Read. II.  Chapter VII. How To Go Into Society  Chapter VIII. How To Travel  Chapter IX. Life At School

# %%
import polars as pl

def process_chunk(lines):
    # Create a DataFrame from the chunk of lines.
    df_chunk = pl.DataFrame({"line": lines})
    # Split each line into tokens by whitespace.
    df_chunk = df_chunk.with_columns(
        pl.col("line").str.split(" ").alias("tokens")
    )
    # Explode tokens so that each token becomes its own row.
    df_chunk = df_chunk.explode("tokens")
    # Count tokens in this chunk.
    total_tokens_chunk = df_chunk.select(pl.count("tokens")).item()
    # Get unique tokens in this chunk.
    unique_tokens_chunk = set(df_chunk["tokens"].to_list())
    # Remove None values if present.
    unique_tokens_chunk.discard(None)
    return total_tokens_chunk, unique_tokens_chunk

chunk_size = 10000  # number of lines per chunk; adjust as needed
total_tokens = 0
unique_tokens_set = set()

# Read the file in chunks.
with open("/content/full_books_text.txt", "r", encoding="utf8") as f:
    lines_chunk = []
    for i, line in enumerate(f):
        lines_chunk.append(line)
        if (i + 1) % chunk_size == 0:
            t_count, unique_chunk = process_chunk(lines_chunk)
            total_tokens += t_count
            unique_tokens_set.update(unique_chunk)
            lines_chunk = []  # reset for the next chunk
    # Process any remaining lines.
    if lines_chunk:
        t_count, unique_chunk = process_chunk(lines_chunk)
        total_tokens += t_count
        unique_tokens_set.update(unique_chunk)

print("Token counts:")
print("Total tokens:", total_tokens)
print("Unique tokens:", len(unique_tokens_set))
# Out:
# Token counts:
# Total tokens: 1068364428
# Unique tokens: 14883525

# %%
# !zip /content/full_books_text_part_aa.zip /content/full_books_text_part_aa
from google.colab import files
files.download('/content/full_books_text_part_aa.zip')
# Out:
#   adding: content/full_books_text_part_aa (deflated 62%)

# %%
# !zip /content/full_books_text_part_ab.zip /content/full_books_text_part_ab
# !zip /content/full_books_text_part_ac.zip /content/full_books_text_part_ac
# !zip /content/full_books_text_part_ad.zip /content/full_books_text_part_ad
# !zip /content/full_books_text_part_ae.zip /content/full_books_text_part_ae
# !zip /content/full_books_text_part_af.zip /content/full_books_text_part_af
# !zip /content/full_books_text_part_ag.zip /content/full_books_text_part_ag
# !zip /content/full_books_text_part_ah.zip /content/full_books_text_part_ah
# Out:
#   adding: content/full_books_text_part_ab (deflated 62%)
#   adding: content/full_books_text_part_ac (deflated 62%)
#   adding: content/full_books_text_part_ad (deflated 62%)
#   adding: content/full_books_text_part_ae (deflated 62%)
#   adding: content/full_books_text_part_af (deflated 62%)
#   adding: content/full_books_text_part_ag (deflated 63%)
#   adding: content/full_books_text_part_ah (deflated 62%)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-fbb008fd127c> in <cell line: 0>()
#       8
#       9 from google.colab import files
# ---> 10 files.download('/content/full_books_text_part_aab.zip')
#      11 files.download('/content/full_books_text_part_ac.zip')
#      12 files.download('/content/full_books_text_part_ad.zip')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/full_books_text_part_aab.zip

# %%
from google.colab import files
files.download('/content/full_books_text_part_ab.zip')
files.download('/content/full_books_text_part_ac.zip')
files.download('/content/full_books_text_part_ad.zip')
files.download('/content/full_books_text_part_ae.zip')
files.download('/content/full_books_text_part_af.zip')
files.download('/content/full_books_text_part_ag.zip')
files.download('/content/full_books_text_part_ah.zip')

# %%
# !unzip /content/natural_instructions_tagged.zip -d /content/natural_instructions_tagged
# Out:
# Archive:  /content/natural_instructions_tagged.zip
#   inflating: /content/natural_instructions_tagged/natural_instructions_tagged.txt

# %%
import os

# Define file paths and directories
extraction_dir = '/content/natural_instructions_tagged'
final_merged_file = '/content/final_merged_data.txt'
books_file_path = '/content/full_books_text.txt'

chunk_size = 1024 * 1024  # 1 MB

# Open the final merged file for writing
with open(final_merged_file, 'w', encoding='utf-8') as final_out:
    # Process each conversation text file one by one
    print("Appending conversation files one by one...")
    for root, dirs, files in os.walk(extraction_dir):
        for file in sorted(files):
            if file.endswith('.txt'):
                file_path = os.path.join(root, file)
                print(f"Processing {file_path} ...")
                with open(file_path, 'r', encoding='utf-8') as infile:
                    while True:
                        chunk = infile.read(chunk_size)
                        if not chunk:
                            break
                        final_out.write(chunk)
                # Write a separator between files (optional)
                final_out.write("\n\n")

    # Append a separator before the book data (optional)
    final_out.write("\n\n========== BOOK DATA ==========\n\n")

    # Now append the book text in chunks
    print("Appending book data...")
    with open(books_file_path, 'r', encoding='utf-8') as book_in:
        while True:
            chunk = book_in.read(chunk_size)
            if not chunk:
                break
            final_out.write(chunk)

print(f"Final merged file created at: {final_merged_file}")
# Out:
# Appending conversation files one by one...
# Processing /content/natural_instructions_tagged/natural_instructions_tagged.txt ...
# Appending book data...
# Final merged file created at: /content/final_merged_data.txt

# %%
# Split the final merged data into 12 parts
# !split -n 12 /content/final_merged_data.txt /content/final_merged_data_part_

# Zip each part into its own file
# !zip /content/final_merged_data_part_aa.zip /content/final_merged_data_part_aa
# !zip /content/final_merged_data_part_ab.zip /content/final_merged_data_part_ab
# !zip /content/final_merged_data_part_ac.zip /content/final_merged_data_part_ac
# !zip /content/final_merged_data_part_ad.zip /content/final_merged_data_part_ad
# !zip /content/final_merged_data_part_ae.zip /content/final_merged_data_part_ae
# !zip /content/final_merged_data_part_af.zip /content/final_merged_data_part_af
# !zip /content/final_merged_data_part_ag.zip /content/final_merged_data_part_ag
# !zip /content/final_merged_data_part_ah.zip /content/final_merged_data_part_ah
# !zip /content/final_merged_data_part_ai.zip /content/final_merged_data_part_ai
# !zip /content/final_merged_data_part_aj.zip /content/final_merged_data_part_aj
# !zip /content/final_merged_data_part_ak.zip /content/final_merged_data_part_ak
# !zip /content/final_merged_data_part_al.zip /content/final_merged_data_part_al
# Out:
#   adding: content/final_merged_data_part_aa (deflated 92%)
#   adding: content/final_merged_data_part_ab (deflated 84%)
#   adding: content/final_merged_data_part_ac (deflated 90%)
#   adding: content/final_merged_data_part_ad (deflated 90%)
#   adding: content/final_merged_data_part_ae (deflated 73%)
#   adding: content/final_merged_data_part_af (deflated 62%)
#   adding: content/final_merged_data_part_ag (deflated 62%)
#   adding: content/final_merged_data_part_ah (deflated 62%)
#   adding: content/final_merged_data_part_ai (deflated 62%)
#   adding: content/final_merged_data_part_aj (deflated 62%)
#   adding: content/final_merged_data_part_ak (deflated 63%)
#   adding: content/final_merged_data_part_al (deflated 62%)

# %%
from google.colab import files

files.download('/content/final_merged_data_part_aa.zip')
files.download('/content/final_merged_data_part_ab.zip')
files.download('/content/final_merged_data_part_ac.zip')
files.download('/content/final_merged_data_part_ad.zip')
files.download('/content/final_merged_data_part_ae.zip')
files.download('/content/final_merged_data_part_af.zip')
files.download('/content/final_merged_data_part_ag.zip')
files.download('/content/final_merged_data_part_ah.zip')
files.download('/content/final_merged_data_part_ai.zip')
files.download('/content/final_merged_data_part_aj.zip')
files.download('/content/final_merged_data_part_ak.zip')
files.download('/content/final_merged_data_part_al.zip')

# %%
#!pip install tiktoken
import os
import tiktoken
import concurrent.futures
from tqdm import tqdm

# Define paths and parameters
merged_file_path = '/content/final_merged_data.txt'
output_tokenized_file = '/content/final_tokenized_data.txt'
chunk_size = 1024 * 1024  # 1 MB

# Function to tokenize a given chunk of text
def tokenize_chunk(chunk):
    # Use the desired encoding (e.g., "gpt2", "cl100k_base", etc.)
    encoding = tiktoken.get_encoding("gpt2")
    return encoding.encode(chunk)

# Read the merged file in chunks
chunks = []
with open(merged_file_path, 'r', encoding='utf-8') as f:
    while True:
        chunk = f.read(chunk_size)
        if not chunk:
            break
        chunks.append(chunk)

# Process tokenization in parallel using ProcessPoolExecutor
tokenized_chunks = []
with concurrent.futures.ProcessPoolExecutor() as executor:
    # Submit all chunks for tokenization and wrap with tqdm for progress
    futures = [executor.submit(tokenize_chunk, chunk) for chunk in chunks]
    for future in tqdm(concurrent.futures.as_completed(futures),
                       total=len(futures),
                       desc="Tokenizing Chunks"):
        tokenized_chunks.append(future.result())

# Optionally, write the tokenized data to a file.
# Here we join tokens with a space (you might choose a different format).
with open(output_tokenized_file, 'w', encoding='utf-8') as out:
    for tokens in tokenized_chunks:
        out.write(" ".join(map(str, tokens)) + "\n")

print(f"Tokenized data saved at: {output_tokenized_file}")
# Out:
# Tokenizing Chunks:  39%|███▊      | 3517/9090 [02:17<04:09, 22.30it/s]

# %%
#!pip install tiktoken
import os
import tiktoken
import concurrent.futures
from tqdm import tqdm

# Define paths and parameters
merged_file_path = '/content/final_merged_data.txt'
output_tokenized_file = '/content/final_tokenized_data.txt'
chunk_size = 1024 * 256  # 256 KB; adjust as needed

# Function to tokenize a given chunk of text
def tokenize_chunk(chunk):
    encoding = tiktoken.get_encoding("gpt2")
    return encoding.encode(chunk)

# Generator to read file in chunks
def read_in_chunks(file_path, chunk_size):
    with open(file_path, 'r', encoding='utf-8') as f:
        while True:
            chunk = f.read(chunk_size)
            if not chunk:
                break
            yield chunk

# Process tokenization in parallel and write output incrementally
with open(output_tokenized_file, 'w', encoding='utf-8') as out:
    # Create a generator for chunks
    chunks = list(read_in_chunks(merged_file_path, chunk_size))

    # Optionally, reduce number of workers if needed
    with concurrent.futures.ProcessPoolExecutor(max_workers=4) as executor:
        futures = {executor.submit(tokenize_chunk, chunk): idx for idx, chunk in enumerate(chunks)}
        for future in tqdm(concurrent.futures.as_completed(futures),
                           total=len(futures),
                           desc="Tokenizing Chunks"):
            tokens = future.result()
            # Write the tokenized chunk immediately
            out.write(" ".join(map(str, tokens)) + "\n")

print(f"Tokenized data saved at: {output_tokenized_file}")
# Out:
# Tokenizing Chunks:  22%|██▏       | 7921/36360 [03:09<10:36, 44.69it/s]

# %%
from google.colab import files

# Define all suffixes from 'ae' to 'al' in order.
parts = ["ac", "ad", "ae", "af", "ag", "ah", "ai", "aj", "ak", "al"]

for suffix in parts:
    file_path = f"/content/final_merged_data_part_{suffix}"
    try:
        files.download(file_path)
        print(f"Downloaded {file_path}")
    except Exception as e:
        print(f"Could not download {file_path}: {e}")
# Out:
# Downloaded /content/final_merged_data_part_ac
# Downloaded /content/final_merged_data_part_ad
# Downloaded /content/final_merged_data_part_ae
# Downloaded /content/final_merged_data_part_af
# Downloaded /content/final_merged_data_part_ag
# Downloaded /content/final_merged_data_part_ah
# Downloaded /content/final_merged_data_part_ai
# Downloaded /content/final_merged_data_part_aj
# Downloaded /content/final_merged_data_part_ak
# Downloaded /content/final_merged_data_part_al

# %%
# !pip install ftfy

import ftfy

original = """â€œO Gaetano,â€ she exclaimed, â€œI do love you so very dearly.
When you look at me your eyes are likeâ€”they are like the eyesâ€â€”here she faltered a
littleâ€”â€œthe eyes of a cow.â€"""

fixed = ftfy.fix_text(original)
print(fixed)
# Out:
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# "O Gaetano," she exclaimed, "I do love you so very dearly.
# When you look at me your eyes are like—they are like the eyes"—here she faltered a
# little—"the eyes of a cow."
